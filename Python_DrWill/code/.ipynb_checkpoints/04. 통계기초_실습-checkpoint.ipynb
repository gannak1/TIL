# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import chisquare
from scipy import stats
import scipy as sp
import statsmodels.api as sm
from statsmodels.formula.api import ols,logit,glm

# %%
df = pd.read_csv('../data/spstat1.csv',sep=',',encoding = 'euc-kr')
df.head(10)
# Out:
#     번호  사용브랜드  사용기간  구매장소  구매가격  정보획득  구입조언  하루사용시간  브랜드이미지  가격만족도  ...  \
# 0  181      1     3     1    15     1     2       1       2      4  ...
# 1   94      1     3     3    20     4     3       3       4      3  ...
# 2   12      1     2     1    25     1     1       1       3      2  ...
# 3  156      1     5     3    26     4     3       1       4      4  ...
# 4   19      1     3     5    30     6     2       3       2      2  ...
# 5  195      1     1     4    30     6     2       2       2      2  ...
# 6  182      1     5     2    40     1     2       2       5      4  ...
# 7  188      1     5     4    40     6     2       2       1      2  ...
# 8  237      1     4     4    40     6     2       5       3      2  ...
# 9  222      1     5     3    40     2     3       2       4      2  ...
#
#    구매중요도9_A/S  구매중요도10_명성   성별  연령  연령2  학력  직업  월수입  결혼  가족수
# 0           4            3   0   4    2   2   4    2   2    3
# 1           4            5   1   3    2   4   4    4   2    3
# 2           4            4   0   4    2   4   7    4   2    1
# 3           4            4   0   6    3   2   2    5   3    1
# 4           3            3   0   2    1   4   9    2   1    3
# 5           2            1   1   1    1   2   1    2   1    3
# 6           4            3   0   5    3   8   3    5   2    1
# 7           2            2   0   1    1   3   1    1   1    2
# 8           3            2   0   2    1   3   8    1   1    1
# 9           2            2   1   2    1   4   4    3   1    1
#
# [10 rows x 29 columns]

# %%
df.tail()
# Out:
#       번호  사용브랜드  사용기간  구매장소  구매가격  정보획득  구입조언  하루사용시간  브랜드이미지  가격만족도  ...  \
# 247  137      2     2     5   200     6     2       3       2      3  ...
# 248  226      2     3     5   200     6     2       1       3      2  ...
# 249   98      2     5     1   200     2     3       2       4      3  ...
# 250  242      2     3     1   200     2     1       2       4      2  ...
# 251   72      2     5     2   250     1     4       2       3      3  ...
#
#      구매중요도9_A/S  구매중요도10_명성   성별  연령  연령2  학력  직업  월수입  결혼  가족수
# 247           1            1   0   2    1   7   8    2   1    2
# 248           2            2   0   2    1   6   4    6   2    2
# 249           2            1   0   3    2   6   4    3   2    2
# 250           5            5   1   1    1   2   1    2   1    1
# 251           2            1   0   3    2   8   3    6   1    1
#
# [5 rows x 29 columns]

# %%
df.구매장소
# Out:
# 0      1
# 1      3
# 2      1
# 3      3
# 4      5
#       ..
# 247    5
# 248    5
# 249    1
# 250    1
# 251    2
# Name: 구매장소, Length: 252, dtype: int64

# %%
df.columns[[1,4,5]]
# Out:
# Index(['사용브랜드', '구매가격', '정보획득'], dtype='object')

# %%
df.loc[:,'학력':'결혼']
# Out:
#      학력  직업  월수입  결혼
# 0     2   4    2   2
# 1     4   4    4   2
# 2     4   7    4   2
# 3     2   2    5   3
# 4     4   9    2   1
# ..   ..  ..  ...  ..
# 247   7   8    2   1
# 248   6   4    6   2
# 249   6   4    3   2
# 250   2   1    2   1
# 251   8   3    6   1
#
# [252 rows x 4 columns]

# %%
df.iloc[1:7,2:5]
# Out:
#    사용기간  구매장소  구매가격
# 1     3     3    20
# 2     2     1    25
# 3     5     3    26
# 4     3     5    30
# 5     1     4    30
# 6     5     2    40

# %%
df.at[5,'구매가격'] # 5행에 있는 '구매가격' 값 표시
# Out:
# 30

# %%
df['구매가격'] < 50 # 조건
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 247    False
# 248    False
# 249    False
# 250    False
# 251    False
# Name: 구매가격, Length: 252, dtype: bool

# %%
df[df['구매가격']<50] # df에서 '구매가격' 50미만이 값(True)만 추출
# Out:
#       번호  사용브랜드  사용기간  구매장소  구매가격  정보획득  구입조언  하루사용시간  브랜드이미지  가격만족도  ...  \
# 0    181      1     3     1    15     1     2       1       2      4  ...
# 1     94      1     3     3    20     4     3       3       4      3  ...
# 2     12      1     2     1    25     1     1       1       3      2  ...
# 3    156      1     5     3    26     4     3       1       4      4  ...
# 4     19      1     3     5    30     6     2       3       2      2  ...
# 5    195      1     1     4    30     6     2       2       2      2  ...
# 6    182      1     5     2    40     1     2       2       5      4  ...
# 7    188      1     5     4    40     6     2       2       1      2  ...
# 8    237      1     4     4    40     6     2       5       3      2  ...
# 9    222      1     5     3    40     2     3       2       4      2  ...
# 10   208      1     2     4    40     6     2       1       2      2  ...
# 11    27      1     2     5    45     5     2       3       3      3  ...
# 127  160      2     1     4    10     6     1       2       1      1  ...
# 128   92      2     3     1    48     1     2       2       2      2  ...
#
#      구매중요도9_A/S  구매중요도10_명성   성별  연령  연령2  학력  직업  월수입  결혼  가족수
# 0             4            3   0   4    2   2   4    2   2    3
# 1             4            5   1   3    2   4   4    4   2    3
# 2             4            4   0   4    2   4   7    4   2    1
# 3             4            4   0   6    3   2   2    5   3    1
# 4             3            3   0   2    1   4   9    2   1    3
# 5             2            1   1   1    1   2   1    2   1    3
# 6             4            3   0   5    3   8   3    5   2    1
# 7             2            2   0   1    1   3   1    1   1    2
# 8             3            2   0   2    1   3   8    1   1    1
# 9             2            2   1   2    1   4   4    3   1    1
# 10            3            3   1   2    1   3   8    1   1    1
# 11            4            4   0   4    2   4   5    2   2    2
# 127           2            2   1   2    1   4  10    3   1    3
# 128           3            3   0   6    3   2   7    3   2    3
#
# [14 rows x 29 columns]

# %%
df[(df['구매가격'] > 150 ) & (df['구매가격'] < 200) ]
# 구매가격이 150초과 200미만 값 추출
# Out:
#       번호  사용브랜드  사용기간  구매장소  구매가격  정보획득  구입조언  하루사용시간  브랜드이미지  가격만족도  ...  \
# 233  206      2     3     4   160     6     1       5       3      1  ...
# 234  140      2     3     4   170     6     3       5       1      2  ...
# 235  128      2     5     4   180     6     4       3       4      5  ...
# 236   25      2     3     5   180     6     5       3       3      3  ...
# 237  149      2     2     3   182     6     2       5       2      3  ...
# 238  244      2     4     1   190     5     5       2       3      5  ...
# 239   90      2     3     2   190     6     2       2       2      4  ...
#
#      구매중요도9_A/S  구매중요도10_명성   성별  연령  연령2  학력  직업  월수입  결혼  가족수
# 233           3            3   1   2    1   5   8    1   1    3
# 234           1            2   1   3    2   4   2    5   1    4
# 235           5            3   1   6    3   1   9    3   3    2
# 236           4            4   1   4    2   6   4    5   1    4
# 237           3            4   1   3    2   4   4    6   2    2
# 238           4            2   0   5    3   4   4    2   2    4
# 239           4            5   0   4    2   4   4    5   1    4
#
# [7 rows x 29 columns]

# %%
df_columns = df.copy()

# %%
df_columns.columns
# Out:
# Index(['번호', '사용브랜드', '사용기간', '구매장소', '구매가격', '정보획득', '구입조언', '하루사용시간',
#        '브랜드이미지', '가격만족도', '재구매의향', '구매중요도1_메모리', '구매중요도2_배터리', '구매중요도3_카메라',
#        '구매중요도4_처리속도', '구매중요도5_보안기능', '구매중요도6_운영체계', '구매중요도7_디자인', '구매중요도8_음질',
#        '구매중요도9_A/S', '구매중요도10_명성 ', '성별', '연령', '연령2', '학력', '직업', '월수입', '결혼',
#        '가족수'],
#       dtype='object')

# %% [markdown]
# # 기술통계

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   번호           252 non-null    int64
#  1   사용브랜드        252 non-null    int64
#  2   사용기간         252 non-null    int64
#  3   구매장소         252 non-null    int64
#  4   구매가격         252 non-null    int64
#  5   정보획득         252 non-null    int64
#  6   구입조언         252 non-null    int64
#  7   하루사용시간       252 non-null    int64
#  8   브랜드이미지       252 non-null    int64
#  9   가격만족도        252 non-null    int64
#  10  재구매의향        252 non-null    int64
#  11  구매중요도1_메모리   252 non-null    int64
#  12  구매중요도2_배터리   252 non-null    int64
#  13  구매중요도3_카메라   252 non-null    int64
#  14  구매중요도4_처리속도  252 non-null    int64
#  15  구매중요도5_보안기능  252 non-null    int64
#  16  구매중요도6_운영체계  252 non-null    int64
#  17  구매중요도7_디자인   252 non-null    int64
#  18  구매중요도8_음질    252 non-null    int64
#  19  구매중요도9_A/S   252 non-null    int64
#  20  구매중요도10_명성   252 non-null    int64
#  21  성별           252 non-null    int64
#  22  연령           252 non-null    int64
#  23  연령2          252 non-null    int64
#  24  학력           252 non-null    int64
#  25  직업           252 non-null    int64
#  26  월수입          252 non-null    int64
#  27  결혼           252 non-null    int64
#  28  가족수          252 non-null    int64
# dtypes: int64(29)
# memory usage: 57.2 KB

# %%
df.describe() # 전체 요약통계량(숫자만 나옴)
# Out:
#                번호       사용브랜드        사용기간        구매장소        구매가격        정보획득  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   126.500000    1.496032    3.091270    2.940476  101.226190    3.924603
# std     72.890329    0.500979    1.328362    1.318135   38.654982    2.193405
# min      1.000000    1.000000    1.000000    1.000000   10.000000    1.000000
# 25%     63.750000    1.000000    2.000000    2.000000   80.000000    1.000000
# 50%    126.500000    1.000000    3.000000    3.000000  100.000000    5.000000
# 75%    189.250000    2.000000    4.000000    4.000000  120.000000    6.000000
# max    252.000000    2.000000    5.000000    5.000000  250.000000    6.000000
#
#              구입조언      하루사용시간      브랜드이미지       가격만족도  ...  구매중요도9_A/S  \
# count  252.000000  252.000000  252.000000  252.000000  ...  252.000000
# mean     2.313492    2.896825    2.730159    2.777778  ...    3.146825
# std      1.111752    1.393379    1.128499    1.024706  ...    1.128352
# min      1.000000    1.000000    1.000000    1.000000  ...    1.000000
# 25%      2.000000    2.000000    2.000000    2.000000  ...    2.000000
# 50%      2.000000    3.000000    3.000000    3.000000  ...    3.000000
# 75%      3.000000    4.000000    3.250000    3.000000  ...    4.000000
# max      5.000000    5.000000    5.000000    5.000000  ...    5.000000
#
#        구매중요도10_명성           성별          연령         연령2          학력  \
# count   252.000000  252.000000  252.000000  252.000000  252.000000
# mean      3.027778    0.500000    3.130952    1.809524    4.484127
# std       1.346096    0.500995    1.244396    0.699622    1.766145
# min       1.000000    0.000000    1.000000    1.000000    1.000000
# 25%       2.000000    0.000000    2.000000    1.000000    4.000000
# 50%       3.000000    0.500000    3.000000    2.000000    4.000000
# 75%       4.000000    1.000000    4.000000    2.000000    6.000000
# max       5.000000    1.000000    6.000000    3.000000    8.000000
#
#                직업         월수입          결혼         가족수
# count  252.000000  252.000000  252.000000  252.000000
# mean     4.678571    3.702381    1.722222    2.468254
# std      2.246701    1.701509    0.499225    0.937799
# min      1.000000    1.000000    1.000000    1.000000
# 25%      3.000000    2.000000    1.000000    2.000000
# 50%      4.000000    4.000000    2.000000    3.000000
# 75%      6.250000    5.000000    2.000000    3.000000
# max     10.000000    6.000000    3.000000    5.000000
#
# [8 rows x 29 columns]

# %%
df['구매가격'].describe()
# Out:
# count    252.000000
# mean     101.226190
# std       38.654982
# min       10.000000
# 25%       80.000000
# 50%      100.000000
# 75%      120.000000
# max      250.000000
# Name: 구매가격, dtype: float64

# %%
df['구매가격'].kurtosis()
# Out:
# 1.3613500036652209

# %%
# 왜도
df['구매가격'].skew()
# Out:
# 0.8074518614845148

# %%
df['사용브랜드']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 247    2
# 248    2
# 249    2
# 250    2
# 251    2
# Name: 사용브랜드, Length: 252, dtype: int64

# %%
df['사용브랜드'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 247    2
# 248    2
# 249    2
# 250    2
# 251    2
# Name: 사용브랜드, Length: 252, dtype: int64>

# %%
df['사용브랜드'].value_counts()
# Out:
# 1    127
# 2    125
# Name: 사용브랜드, dtype: int64

# %%
from matplotlib import font_manager,rc,rcParams
rc('font',family = 'Malgun Gothic')
rcParams['font.family']
# Out:
# ['Malgun Gothic']

# %%
# %matplotlib inline
# 라인 그려주는거
df['사용브랜드'].replace([1,2],['삼성','애플']).value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['성별']
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 247    0
# 248    0
# 249    0
# 250    1
# 251    0
# Name: 성별, Length: 252, dtype: int64

# %%
df['성별'].value_counts()
# Out:
# 0    126
# 1    126
# Name: 성별, dtype: int64

# %%
# %matplotlib inline
df['성별'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
# %matplotlib inline
df['구매장소'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='구매장소'>

# %% [markdown]
# # 교차분석

# %%
pd.crosstab(df['월수입'],df['사용브랜드'])
# Out:
# 사용브랜드   1   2
# 월수입
# 1      20  13
# 2      14  22
# 3      28  24
# 4      20  17
# 5      12  28
# 6      33  21

# %%
df['사용브랜드_수정'] = df['사용브랜드'].replace([1,2],['삼성','애플'])
df.head()
# Out:
#     번호  사용브랜드  사용기간  구매장소  구매가격  정보획득  구입조언  하루사용시간  브랜드이미지  가격만족도  ...  \
# 0  181      1     3     1    15     1     2       1       2      4  ...
# 1   94      1     3     3    20     4     3       3       4      3  ...
# 2   12      1     2     1    25     1     1       1       3      2  ...
# 3  156      1     5     3    26     4     3       1       4      4  ...
# 4   19      1     3     5    30     6     2       3       2      2  ...
#
#    구매중요도10_명성   성별  연령  연령2  학력  직업  월수입  결혼  가족수  사용브랜드_수정
# 0            3   0   4    2   2   4    2   2    3        삼성
# 1            5   1   3    2   4   4    4   2    3        삼성
# 2            4   0   4    2   4   7    4   2    1        삼성
# 3            4   0   6    3   2   2    5   3    1        삼성
# 4            3   0   2    1   4   9    2   1    3        삼성
#
# [5 rows x 30 columns]

# %%
pd.crosstab(df['월수입'],df['사용브랜드'])
# Out:
# 사용브랜드   1   2
# 월수입
# 1      20  13
# 2      14  22
# 3      28  24
# 4      20  17
# 5      12  28
# 6      33  21

# %%
chisquare(df['월수입'],df['사용브랜드'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_584/2371912771.py in <module>
# ----> 1 chisquare(df['월수입'],df['사용브랜드'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in chisquare(f_obs, f_exp, ddof, axis)
#    6850
#    6851     """
# -> 6852     return power_divergence(f_obs, f_exp=f_exp, ddof=ddof, axis=axis,
#    6853                             lambda_="pearson")
#    6854
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in power_divergence(f_obs, f_exp, ddof, axis, lambda_)
#    6692                    f"of {rtol}, but the percent differences are:\n"
#    6693                    f"{relative_diff}")
# -> 6694             raise ValueError(msg)
#    6695
#    6696     else:
#
# ValueError: For each axis slice, the sum of the observed frequencies must agree with the sum of the expected frequencies to a relative tolerance of 1e-08, but the percent differences are:
# 1.4748010610079576

# %%
import numpy as np
fobs = np.array([10,20])
fexp = np.array([30,60])
# adjust the totals
# gives array([10., 20.]), the same as observed
fexp = fexp * (np.sum(fobs)/np.sum(fexp)) 
chisquare(f_obs=fobs, f_exp=fexp)
# the correct result
# Power_divergenceResult(statistic=0.0, pvalue=1.0)

# 관찰빈도(fobs)와 기대빈도(fexp)가 정확히 일치 해야 함 
# 한 벡터는 다른 벡터의 정확한 배수여야 함 (p-value =1 >> 전혀 유효하지 않음)
# (f_obs=[10,20], f_exp=[30,60])
# Power_divergenceResult(statistic=40.0, pvalue=2.5396285894708634e-10)
# p-value가 0에 가까우기 때문에 유효함 
# ((10-30)**2 /30) + ((20-60)** 2 / 60) = 40
# Out:
# Power_divergenceResult(statistic=0.0, pvalue=1.0)

# %%
import numpy as np
fobs = df.월수입
fexp = df.사용브랜드
fexp = fexp * (np.sum(fobs)/np.sum(fexp)) 
chisquare(f_obs=fobs, f_exp=fexp)
# Out:
# Power_divergenceResult(statistic=343.26420150053593, pvalue=9.618060771117479e-05)

# %%
pd.crosstab(df['구매장소'],df['성별'])
# Out:
# 성별     0   1
# 구매장소
# 1     24  19
# 2     42  29
# 3      9  13
# 4     38  52
# 5     13  13

# %%
df['구매장소']
# Out:
# 0      1
# 1      3
# 2      1
# 3      3
# 4      5
#       ..
# 247    5
# 248    5
# 249    1
# 250    1
# 251    2
# Name: 구매장소, Length: 252, dtype: int64

# %%
chisquare(df['구매장소'])
# Out:
# Power_divergenceResult(statistic=148.31174089068827, pvalue=0.9999999645077914)

# %%
# ?chisquare  # 레벤테스트 -> 등분산이라는 가정을 함, 하지
# Out:
# Object `chisquare  # 레벤테스트 -> 등분산이라는 가정을 함, 하지` not found.

# %%
chisquare(df['구매장소'],ddof=[0,1]) # 자유도를 조정해봄
# Out:
# Power_divergenceResult(statistic=148.31174089068827, pvalue=array([0.99999996, 0.99999995]))

# %%
result = pd.crosstab(df.월수입,df.사용브랜드)
result
# Out:
# 사용브랜드   1   2
# 월수입
# 1      20  13
# 2      14  22
# 3      28  24
# 4      20  17
# 5      12  28
# 6      33  21

# %%
stats.chi2_contingency(observed=result)
# https://brunch.co.kr/@linecard/623
# 카이제곱 값: 12.86516581745558
# p-value =  0.024675611662926037
# - 통계적으로 유의한 차이가 있음: 귀무가설 기각
# - 월수입에 따라 사용브랜드 차이가 있다.
# - df(자유도, degree of freedom) : k-1 >> 5 (= 6-1)
# array : 기대치 (Expected Value)
# Out:
# (12.86516581745558,
#  0.024675611662926037,
#  5,
#  array([[16.63095238, 16.36904762],
#         [18.14285714, 17.85714286],
#         [26.20634921, 25.79365079],
#         [18.6468254 , 18.3531746 ],
#         [20.15873016, 19.84126984],
#         [27.21428571, 26.78571429]]))

# %% [markdown]
# # T검정

# %%
df['구매가격'].values
# Out:
# array([ 15,  20,  25,  26,  30,  30,  40,  40,  40,  40,  40,  45,  50,
#         50,  50,  50,  50,  50,  50,  50,  50,  50,  60,  60,  60,  60,
#         60,  69,  70,  70,  70,  70,  70,  70,  70,  70,  70,  70,  70,
#         70,  70,  70,  72,  75,  75,  75,  80,  80,  80,  80,  80,  80,
#         80,  80,  80,  80,  80,  80,  80,  80,  80,  80,  80,  80,  85,
#         89,  90,  90,  90,  90,  90,  90,  90,  90,  90,  90,  90,  90,
#         90,  90,  90,  90,  90,  90,  90,  90,  95,  99, 100, 100, 100,
#        100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100,
#        100, 100, 100, 100, 100, 100, 100, 110, 110, 120, 120, 120, 120,
#        120, 120, 120, 120, 120, 120, 130, 130, 130, 150,  10,  48,  50,
#         50,  70,  70,  70,  70,  75,  80,  80,  80,  80,  89,  90,  90,
#         90,  90,  90,  90,  90,  90,  90,  90,  90,  90,  90,  90,  90,
#         98, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100,
#        100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100,
#        100, 100, 100, 100, 110, 120, 120, 120, 120, 120, 120, 120, 120,
#        120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120,
#        120, 120, 126, 128, 130, 130, 130, 130, 130, 130, 138, 140, 150,
#        150, 150, 150, 150, 150, 150, 150, 150, 150, 150, 150, 150, 160,
#        170, 180, 180, 182, 190, 190, 200, 200, 200, 200, 200, 200, 200,
#        200, 200, 200, 200, 250], dtype=int64)

# %%
mean = df['구매가격'].values

# %%
df['사용브랜드']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 247    2
# 248    2
# 249    2
# 250    2
# 251    2
# Name: 사용브랜드, Length: 252, dtype: int64

# %%
df[df['사용브랜드'] == 1].구매가격.values
# Out:
# array([ 15,  20,  25,  26,  30,  30,  40,  40,  40,  40,  40,  45,  50,
#         50,  50,  50,  50,  50,  50,  50,  50,  50,  60,  60,  60,  60,
#         60,  69,  70,  70,  70,  70,  70,  70,  70,  70,  70,  70,  70,
#         70,  70,  70,  72,  75,  75,  75,  80,  80,  80,  80,  80,  80,
#         80,  80,  80,  80,  80,  80,  80,  80,  80,  80,  80,  80,  85,
#         89,  90,  90,  90,  90,  90,  90,  90,  90,  90,  90,  90,  90,
#         90,  90,  90,  90,  90,  90,  90,  90,  95,  99, 100, 100, 100,
#        100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100,
#        100, 100, 100, 100, 100, 100, 100, 110, 110, 120, 120, 120, 120,
#        120, 120, 120, 120, 120, 120, 130, 130, 130, 150], dtype=int64)

# %%
mean1 = df[df['사용브랜드'] == 1].구매가격.values
mean2 = df[df['사용브랜드'] == 2].구매가격.values

# %%
# %matplotlib inline

sns.distplot(mean1, kde=True, fit=sp.stats.norm)
sns.distplot(mean2, kde=True, fit=sp.stats.norm)
plt.show()
sp.stats.shapiro(mean1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ShapiroResult(statistic=0.9720979928970337, pvalue=0.009973179548978806)

# %%
sp.stats.levene(mean1,mean2)

# 레빈 테스트 결과, 사용브랜드 간(두 집단) 등분산성 가정은 위배됨
# p-value가 0.0003 <0.05 >> 등분산성 가정 위배
# H0 : mean1, mean2 분산은 같다 (등분산)
# Out:
# LeveneResult(statistic=13.443717170975082, pvalue=0.00030027808643848084)

# %%
# 독립 표본  t 검정 (등분산성 위배 조건)
stats.ttest_ind(mean1,mean2, equal_var = False) # equal_var -> 등분산성 가정하는지?
# pvalue=3.598124628532717e-17) < 0.05 이므로 , 두 집단간 유의한 차이가 있음
# Out:
# Ttest_indResult(statistic=-9.2004623883404, pvalue=3.598124628532717e-17)

# %%
mean = df['재구매의향'].values
mean1 = df[df['재구매의향'] == 1].구매가격.values
mean2 = df[df['재구매의향'] == 2].구매가격.values

# %%
# %matplotlib inline

sns.distplot(mean1, kde=False, fit=sp.stats.norm)
sns.distplot(mean2, kde=False, fit=sp.stats.norm)
plt.show()
sp.stats.shapiro(mean1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ShapiroResult(statistic=0.9278486967086792, pvalue=0.030400117859244347)

# %%
sp.stats.levene(mean1,mean2)
# pvalue = 0.731546581258
# Out:
# LeveneResult(statistic=1.7867539131444574, pvalue=0.18444894613601984)

# %%
# independent 2 sample t test
stats.ttest_ind(mean1,mean2,equal_var = True)
# pvalue=0.8761444757167405 > 0.05
# 통계적으로 유의미한 차이가 없음
# Out:
# Ttest_indResult(statistic=0.15627063811767203, pvalue=0.8761444757167405)

# %% [markdown]
# ### 분산분석

# %%
anova1 = df[df['연령2'] == 1].재구매의향.values
anova2 = df[df['연령2'] == 2].재구매의향.values
anova3 = df[df['연령2'] == 3].재구매의향.values
# 연령2 : 3집단으로 줄임(요인분석한 결과값임)

# %%
sns.distplot(anova1,kde = False, fit = sp.stats.norm)
sns.distplot(anova2,kde = False, fit = sp.stats.norm)
sns.distplot(anova3,kde = False, fit = sp.stats.norm)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
stats.f_oneway(anova1,anova2,anova3)
# pvalue=1.613686022426391e-25 < 0.05
# H0 : 연령2의 세 집단간 재구매의향은 차이가 없다
# 새 집단 간 모두 차이가 없다고 말할 수 없다. >> 사후 테스트 필요
# Out:
# F_onewayResult(statistic=72.42612494637737, pvalue=1.613686022426391e-25)

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

tukey = pairwise_tukeyhsd(endog = df['재구매의향'], # data
                         groups = df['연령2'],      # group
                         alpha = 0.05)              # 유의수준(siginificance level)

tukey.summary()
# 결과 해석
# 1-3, 2-3 집단간 평균 차이 존재: Pvalue  ~= 0.001, 귀무가설 기각(reject = True)
# 
# meandiff 평균간 차이, p-adj 조정된 p_value reject 귀무가설 기각인가
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
tukey.plot_simultaneous()
plt.vline(x = 49.57, ymin = -0.5, ymax = 4.5, color = 'red')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\sandbox\stats\multicomp.py:775: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_yticklabels(np.insert(self.groupsunique.astype(str), 0, ''))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_584/2756763200.py in <module>
#       1 tukey.plot_simultaneous()
# ----> 2 plt.vline(x = 49.57, ymin = -0.5, ymax = 4.5, color = 'red')
#       3 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'vline'

# %%
# 연령에 따른 구매가격 차이

anova1 = df[df['연령2'] == 1].구매가격.values
anova2 = df[df['연령2'] == 2].구매가격.values
anova3 = df[df['연령2'] == 3].구매가격.values
# 연령2 : 3집단으로 줄임(요인분석한 결과값임)

stats.f_oneway(anova1,anova2,anova3)
# 일원 분산 분석 결과, f 통계량은 0.8181036982598708, pvalue=0.44245014422691564 >  0.05 임
# 세 집단간 유의한 차이가 없음
# Out:
# F_onewayResult(statistic=0.8181036982598708, pvalue=0.44245014422691564)

# %%
sns.distplot(anova1, kde = False, fit = sp.stats.norm)
sns.distplot(anova2, kde = False, fit = sp.stats.norm)
sns.distplot(anova3, kde = False, fit = sp.stats.norm)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# #### 상관분석

# %%
sp.stats.pearsonr(df.재구매의향, df.구입조언) # t value > 0.4정도면 약간 상관이 있음, 0.6정도면 유의미할정도로 상관이 존재챆
# Out:
# (0.41783620648818565, 4.546075388272401e-12)

# %%
corr = sp.stats.pearsonr(df.재구매의향, df.구입조언) 
print('상관관계=%.2f, p-values=%.2f'%(corr))
# Out:
# 상관관계=0.42, p-values=0.00

# %%
df.corr(method = 'pearson')
# Out:
#                    번호     사용브랜드      사용기간      구매장소      구매가격      정보획득  \
# 번호           1.000000 -0.047623  0.055364 -0.025606 -0.086080 -0.051147
# 사용브랜드       -0.047623  1.000000  0.015513 -0.009409  0.504192 -0.056471
# 사용기간         0.055364  0.015513  1.000000 -0.033291  0.055694 -0.041385
# 구매장소        -0.025606 -0.009409 -0.033291  1.000000  0.000500  0.154155
# 구매가격        -0.086080  0.504192  0.055694  0.000500  1.000000  0.036478
# 정보획득        -0.051147 -0.056471 -0.041385  0.154155  0.036478  1.000000
# 구입조언        -0.050270 -0.022794  0.163995  0.129688  0.166607  0.044041
# 하루사용시간       0.016985 -0.023418 -0.031484  0.096426  0.162502  0.036552
# 브랜드이미지       0.136440 -0.086466  0.364656 -0.112618  0.016474 -0.109654
# 가격만족도        0.078784 -0.048290  0.275456 -0.101271  0.121168  0.001379
# 재구매의향        0.160107  0.005639  0.437576 -0.043883  0.084073 -0.035400
# 구매중요도1_메모리  -0.018018 -0.585049 -0.048485 -0.027008 -0.183833  0.075859
# 구매중요도2_배터리  -0.053099 -0.340735  0.010242  0.003947  0.031399  0.052697
# 구매중요도3_카메라  -0.151147 -0.106874 -0.172805 -0.019319 -0.087194  0.083842
# 구매중요도4_처리속도 -0.020964 -0.375996 -0.065231 -0.044312 -0.105032  0.080248
# 구매중요도5_보안기능 -0.034794 -0.326274  0.066387 -0.060124 -0.037961  0.107348
# 구매중요도6_운영체계 -0.119073 -0.415133 -0.101203 -0.040761 -0.113967  0.017707
# 구매중요도7_디자인  -0.195526 -0.064535 -0.181043 -0.045440 -0.150045  0.088673
# 구매중요도8_음질   -0.137432 -0.140730  0.019943 -0.001288 -0.079770  0.022916
# 구매중요도9_A/S   0.052534 -0.319646  0.049501 -0.015530 -0.061142  0.031857
# 구매중요도10_명성  -0.010902 -0.268644 -0.070494 -0.003555 -0.089322  0.084373
# 성별          -0.010801  0.007937  0.020953  0.111610  0.054414  0.208469
# 연령          -0.038587  0.035986  0.289194  0.063064  0.026217 -0.028481
# 연령2         -0.003438  0.020569  0.280284  0.039499  0.047563 -0.050936
# 학력          -0.018785  0.015688  0.135625  0.005582  0.102732 -0.030649
# 직업           0.014950  0.078505 -0.067558  0.052707 -0.021546  0.040337
# 월수입         -0.201912  0.000946  0.170708 -0.052339  0.140954  0.024921
# 결혼          -0.155690  0.011505  0.200593 -0.025227  0.010288 -0.008287
# 가족수          0.020283 -0.012989 -0.031246 -0.125619  0.031466  0.110201
#
#                  구입조언    하루사용시간    브랜드이미지     가격만족도  ...  구매중요도9_A/S  \
# 번호          -0.050270  0.016985  0.136440  0.078784  ...    0.052534
# 사용브랜드       -0.022794 -0.023418 -0.086466 -0.048290  ...   -0.319646
# 사용기간         0.163995 -0.031484  0.364656  0.275456  ...    0.049501
# 구매장소         0.129688  0.096426 -0.112618 -0.101271  ...   -0.015530
# 구매가격         0.166607  0.162502  0.016474  0.121168  ...   -0.061142
# 정보획득         0.044041  0.036552 -0.109654  0.001379  ...    0.031857
# 구입조언         1.000000  0.152128  0.255051  0.365651  ...    0.315692
# 하루사용시간       0.152128  1.000000 -0.045647  0.050846  ...    0.019810
# 브랜드이미지       0.255051 -0.045647  1.000000  0.512966  ...    0.240870
# 가격만족도        0.365651  0.050846  0.512966  1.000000  ...    0.283316
# 재구매의향        0.417836  0.005590  0.718376  0.687236  ...    0.259575
# 구매중요도1_메모리  -0.147773  0.007177  0.003874 -0.115503  ...    0.102691
# 구매중요도2_배터리  -0.023678  0.067658  0.056284 -0.062136  ...    0.196167
# 구매중요도3_카메라  -0.323500 -0.120396 -0.160745 -0.338452  ...   -0.195200
# 구매중요도4_처리속도 -0.162144 -0.005476 -0.060925 -0.156917  ...    0.005682
# 구매중요도5_보안기능  0.251546  0.048557  0.218322  0.255049  ...    0.704430
# 구매중요도6_운영체계 -0.206953 -0.002158 -0.050563 -0.149211  ...    0.057104
# 구매중요도7_디자인  -0.384920 -0.126104 -0.262693 -0.414275  ...   -0.316228
# 구매중요도8_음질   -0.167400 -0.022253 -0.061900 -0.145609  ...   -0.023625
# 구매중요도9_A/S   0.315692  0.019810  0.240870  0.283316  ...    1.000000
# 구매중요도10_명성   0.199148  0.010031  0.141335  0.218231  ...    0.799956
# 성별           0.096565 -0.062779 -0.007047 -0.085366  ...    0.045810
# 연령           0.623919  0.033098  0.300457  0.494699  ...    0.369304
# 연령2          0.640517  0.024716  0.338334  0.518681  ...    0.328284
# 학력           0.202405  0.225983  0.089793  0.057481  ...    0.040158
# 직업          -0.178018  0.023726 -0.023346  0.015575  ...   -0.122752
# 월수입          0.203266  0.107988  0.113624  0.137864  ...    0.168111
# 결혼           0.243664 -0.087184  0.121006  0.307197  ...    0.270728
# 가족수         -0.011434  0.085902  0.029519  0.079693  ...   -0.057701
#
#              구매중요도10_명성             성별        연령           연령2        학력  \
# 번호             -0.010902 -1.080086e-02 -0.038587 -3.437524e-03 -0.018785
# 사용브랜드          -0.268644  7.936758e-03  0.035986  2.056873e-02  0.015688
# 사용기간           -0.070494  2.095292e-02  0.289194  2.802837e-01  0.135625
# 구매장소           -0.003555  1.116104e-01  0.063064  3.949891e-02  0.005582
# 구매가격           -0.089322  5.441430e-02  0.026217  4.756285e-02  0.102732
# 정보획득            0.084373  2.084692e-01 -0.028481 -5.093567e-02 -0.030649
# 구입조언            0.199148  9.656477e-02  0.623919  6.405167e-01  0.202405
# 하루사용시간          0.010031 -6.277929e-02  0.033098  2.471600e-02  0.225983
# 브랜드이미지          0.141335 -7.046798e-03  0.300457  3.383337e-01  0.089793
# 가격만족도           0.218231 -8.536627e-02  0.494699  5.186812e-01  0.057481
# 재구매의향           0.147048 -6.897864e-03  0.477725  5.198256e-01  0.104232
# 구매중요도1_메모리      0.110390  1.296455e-02 -0.187183 -1.747130e-01  0.018014
# 구매중요도2_배터리      0.179381 -3.231073e-03 -0.061232 -8.726150e-02  0.100078
# 구매중요도3_카메라     -0.093054  1.101127e-01 -0.463506 -4.583293e-01  0.018792
# 구매중요도4_처리속도    -0.005932 -9.892266e-03 -0.223312 -2.010448e-01  0.043873
# 구매중요도5_보안기능     0.575520 -3.452179e-02  0.282633  2.559839e-01 -0.000749
# 구매중요도6_운영체계     0.085127 -1.512494e-02 -0.283037 -2.622105e-01  0.005217
# 구매중요도7_디자인     -0.167307  1.485585e-01 -0.510282 -5.254928e-01 -0.072286
# 구매중요도8_음질      -0.006820  1.701276e-01 -0.211704 -2.076630e-01 -0.050354
# 구매중요도9_A/S      0.799956  4.581016e-02  0.369304  3.282842e-01  0.040158
# 구매중요도10_명성      1.000000  5.612294e-02  0.235664  2.044719e-01 -0.019086
# 성별              0.056123  1.000000e+00  0.009586 -6.467458e-18  0.022513
# 연령              0.235664  9.585741e-03  1.000000  9.348512e-01  0.163192
# 연령2             0.204472 -6.467458e-18  0.934851  1.000000e+00  0.181329
# 학력             -0.019086  2.251316e-02  0.163192  1.813289e-01  1.000000
# 직업             -0.143263 -2.353798e-01 -0.164438 -1.709077e-01 -0.220675
# 월수입             0.125387  2.406943e-01  0.217933  2.266256e-01  0.315942
# 결혼              0.219030 -1.592930e-02  0.501295  4.524729e-01  0.089870
# 가족수             0.030684  3.391902e-02 -0.025442  2.891572e-03 -0.077279
#
#                    직업       월수입        결혼       가족수
# 번호           0.014950 -0.201912 -0.155690  0.020283
# 사용브랜드        0.078505  0.000946  0.011505 -0.012989
# 사용기간        -0.067558  0.170708  0.200593 -0.031246
# 구매장소         0.052707 -0.052339 -0.025227 -0.125619
# 구매가격        -0.021546  0.140954  0.010288  0.031466
# 정보획득         0.040337  0.024921 -0.008287  0.110201
# 구입조언        -0.178018  0.203266  0.243664 -0.011434
# 하루사용시간       0.023726  0.107988 -0.087184  0.085902
# 브랜드이미지      -0.023346  0.113624  0.121006  0.029519
# 가격만족도        0.015575  0.137864  0.307197  0.079693
# 재구매의향       -0.011976  0.112335  0.202286  0.024099
# 구매중요도1_메모리  -0.061743  0.035864 -0.098591  0.035993
# 구매중요도2_배터리  -0.071072  0.049539  0.014051  0.033454
# 구매중요도3_카메라   0.028458 -0.022536 -0.178627 -0.010813
# 구매중요도4_처리속도 -0.047742  0.053607 -0.051843 -0.044375
# 구매중요도5_보안기능 -0.125818  0.171853  0.204016  0.055859
# 구매중요도6_운영체계 -0.030114  0.025597 -0.103552  0.072978
# 구매중요도7_디자인  -0.023820 -0.030203 -0.252893 -0.016545
# 구매중요도8_음질   -0.128577  0.125864 -0.129694 -0.024584
# 구매중요도9_A/S  -0.122752  0.168111  0.270728 -0.057701
# 구매중요도10_명성  -0.143263  0.125387  0.219030  0.030684
# 성별          -0.235380  0.240694 -0.015929  0.033919
# 연령          -0.164438  0.217933  0.501295 -0.025442
# 연령2         -0.170908  0.226626  0.452473  0.002892
# 학력          -0.220675  0.315942  0.089870 -0.077279
# 직업           1.000000 -0.329444 -0.133204 -0.047408
# 월수입         -0.329444  1.000000  0.324409 -0.032161
# 결혼          -0.133204  0.324409  1.000000 -0.095499
# 가족수         -0.047408 -0.032161 -0.095499  1.000000
#
# [29 rows x 29 columns]

# %% [markdown]
# #### 회귀분석

# %%
ols(formula='재구매의향 ~ 성별+연령+학력+월수입+사용기간+구매가격+구입조언+브랜드이미지+가격만족도+구매중요도1_메모리+하루사용시간', data=df).fit().summary()
#             종속변수 ~ .(전부다),data=df).fit().summary()
# R-squared 결정계수 AIC BIC 적을수록 적음
# intercept 상수값 ax-b에서 b
# 회귀식 = (coef_사용기간 X 사용기간 + coef_구입조언 X 구입조언 + coef_브랜드이미지 X 브랜드이미지 + coef_가격만족도 X 가격만족도 - intercept)
# t값 기각력, P > |t| pvalue
#[0.025]
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  재구매의향   R-squared:                       0.702
# Model:                            OLS   Adj. R-squared:                  0.689
# Method:                 Least Squares   F-statistic:                     51.44
# Date:                Tue, 08 Feb 2022   Prob (F-statistic):           7.46e-57
# Time:                        11:34:04   Log-Likelihood:                -240.30
# No. Observations:                 252   AIC:                             504.6
# Df Residuals:                     240   BIC:                             547.0
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1580      0.226     -0.699      0.485      -0.603       0.287
# 성별             0.0573      0.085      0.672      0.502      -0.111       0.225
# 연령             0.0503      0.047      1.071      0.285      -0.042       0.143
# 학력             0.0062      0.025      0.246      0.806      -0.043       0.056
# 월수입           -0.0368      0.027     -1.372      0.171      -0.090       0.016
# 사용기간           0.1292      0.034      3.807      0.000       0.062       0.196
# 구매가격        3.583e-06      0.001      0.003      0.997      -0.002       0.002
# 구입조언           0.1206      0.049      2.459      0.015       0.024       0.217
# 브랜드이미지         0.4527      0.044     10.261      0.000       0.366       0.540
# 가격만족도          0.3961      0.052      7.626      0.000       0.294       0.498
# 구매중요도1_메모리    -0.0426      0.028     -1.538      0.125      -0.097       0.012
# 하루사용시간        -0.0010      0.031     -0.033      0.974      -0.062       0.060
# ==============================================================================
# Omnibus:                        4.865   Durbin-Watson:                   2.144
# Prob(Omnibus):                  0.088   Jarque-Bera (JB):                4.345
# Skew:                          -0.249   Prob(JB):                        0.114
# Kurtosis:                       2.592   Cond. No.                         611.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sns.lmplot(y = '재구매의향',x = '사용기간',data = df)
plt.show()
