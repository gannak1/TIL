# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import time
from datetime import datetime
import itertools
import gc
import pickle
from xgboost import XGBRegressor
from xgboost import plot_importance

# %matplotlib inline

# %%
# 데이터 불러오기

sales = pd.read_csv('./data/sales_train.csv')
items = pd.read_csv('./data/items.csv')
item_categories = pd.read_csv('./data/item_categories.csv')
shops = pd.read_csv('./data/shops.csv')
test = pd.read_csv('./data/test.csv')

# %% [markdown]
# # 1. Preprocessing

# %% [markdown]
# ## 1) sales data

# %%
sales.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
sales.shape
# Out:
# (2935849, 6)

# %%
sales.corr()   # 상관계수
# Out:
#                 date_block_num   shop_id   item_id  item_price  item_cnt_day
# date_block_num        1.000000  0.019273  0.009356    0.095010      0.009402
# shop_id               0.019273  1.000000  0.029396   -0.024034     -0.005230
# item_id               0.009356  0.029396  1.000000   -0.134104      0.016650
# item_price            0.095010 -0.024034 -0.134104    1.000000      0.011197
# item_cnt_day          0.009402 -0.005230  0.016650    0.011197      1.000000

# %%
sales.describe()
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day
# count    2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06
# mean     1.456991e+01  3.300173e+01  1.019723e+04  8.908532e+02  1.242641e+00
# std      9.422988e+00  1.622697e+01  6.324297e+03  1.729800e+03  2.618834e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -2.200000e+01
# 25%      7.000000e+00  2.200000e+01  4.476000e+03  2.490000e+02  1.000000e+00
# 50%      1.400000e+01  3.100000e+01  9.343000e+03  3.990000e+02  1.000000e+00
# 75%      2.300000e+01  4.700000e+01  1.568400e+04  9.990000e+02  1.000000e+00
# max      3.300000e+01  5.900000e+01  2.216900e+04  3.079800e+05  2.169000e+03

# %% [markdown]
# ### 날짜형식 변환 매우빠름

# %%
sales.date = sales.date.astype('datetime64')
#sale_t.dt.strptime(x,'%d.%m.%Y')

# %% [markdown]
# ### 중복데이터 처리

# %%
sales.duplicated().sum()  # sales데이터 중복행 6개
# Out:
# 6

# %%
# 나머지 데이터프레임 중복값 확인
print(test.duplicated().sum())
print(items.duplicated().sum())
print(item_categories.duplicated().sum())
print(shops.duplicated().sum())
# Out:
# 0
# 0
# 0
# 0

# %%
# sales 중복데이터 6개 삭제
sales = sales.drop_duplicates()
sales.shape  # (2935849, 6) -> (2935843, 6)
# Out:
# (2935843, 6)

# %% [markdown]
# ### 결측치 처리

# %%
# 결측치 없음
sales.isnull().sum()
# Out:
# date              0
# date_block_num    0
# shop_id           0
# item_id           0
# item_price        0
# item_cnt_day      0
# dtype: int64

# %% [markdown]
# ### 이상치 처리
# - boxplot 활용해 이상치 확인

# %%
plt.figure(figsize=(12,3))
sns.boxplot(x='item_price', data=sales)
plt.figure(figsize=(12,3))
sns.boxplot(x='item_cnt_day', data=sales)
plt.show()

# %%
plt.figure(figsize=(12,3))
sns.boxplot(x = 'date_block_num', y = 'item_price', data = sales)
plt.figure(figsize=(12,3))
sns.boxplot(x = 'date_block_num', y = 'item_cnt_day', data = sales)
plt.show()

# %%
# 뚜렷한 이상치를 우선 제거 -> 분석하면서 확인하기
sales = sales[sales.item_cnt_day < 500]
sales = sales[sales.item_price < 50000]

# %%
plt.figure(figsize=(12,3))
sns.boxplot(x='item_price', data=sales);
plt.figure(figsize=(12,3))
sns.boxplot(x='item_cnt_day', data=sales)

plt.show()

# %% [markdown]
# ### 특정 행 제거
# - item_price 컬럼과 item_cnt_day 컬럼의 음수값 처리하기

# %%
# item_price 가 0 이하인 경우
(sales.item_price <= 0).sum()
# Out:
# 1

# %%
sales = sales[sales.item_price > 0] # 음수 값 처리

# %%
# 팔린 상품의 개수가 (-) 인 경우 -> 행 삭제?, 이전 주문과 함께 삭제
(sales['item_cnt_day'] < 0).sum()
# Out:
# 7356

# %%
sales = sales[sales.item_cnt_day >= 0] # 음수 값 처리

# %% [markdown]
# ## 2) items data

# %%
items.head()
# Out:
#                                            item_name  item_id  item_category_id
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0                40
# 1  !ABBYY FineReader 12 Professional Edition Full...        1                76
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2                40
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3                40
# 4        ***КОРОБКА (СТЕКЛО)                       D        4                40

# %%
# item_id와 item_category_id가 숫자로 매핑되어있어 name만 drop
items.drop(['item_name'], axis=1, inplace=True)
items.head()
# Out:
#    item_id  item_category_id
# 0        0                40
# 1        1                76
# 2        2                40
# 3        3                40
# 4        4                40

# %% [markdown]
# ## 3) item_categories data
# - item_category_name을 라벨인코딩하여 type_id 컬럼 생성

# %%
item_categories.head()
# Out:
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4

# %%
type_encoder = LabelEncoder()

item_categories['split_name'] = item_categories['item_category_name'].str.split(' - ')
item_categories['type'] = item_categories['split_name'].map(lambda x: x[0].strip())
item_categories['type_id'] = type_encoder.fit_transform(item_categories['type'])

# %%
item_categories.head()
# Out:
#         item_category_name  item_category_id  ...        type type_id
# 0  PC - Гарнитуры/Наушники                 0  ...          PC       0
# 1         Аксессуары - PS2                 1  ...  Аксессуары       1
# 2         Аксессуары - PS3                 2  ...  Аксессуары       1
# 3         Аксессуары - PS4                 3  ...  Аксессуары       1
# 4         Аксессуары - PSP                 4  ...  Аксессуары       1
#
# [5 rows x 5 columns]

# %%
item_categories = item_categories[['item_category_id','type_id']]
item_categories.head()
# Out:
#    item_category_id  type_id
# 0                 0        0
# 1                 1        1
# 2                 2        1
# 3                 3        1
# 4                 4        1

# %% [markdown]
# ## 4) shops data
# - shop_name컬럼의 지역명을 라벨인코딩하여 city_id 컬럼 생성

# %%
shops.head()
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4

# %%
shops.loc[shops.shop_name == 'Сергиев Посад ТЦ "7Я"', 'shop_name'] = 'СергиевПосад ТЦ "7Я"'

# %%
# 공백(' ')을 기준으로 분리
shops['city'] = shops['shop_name'].str.split(' ').map(lambda x: x[0])
shops.head()
# Out:
#                         shop_name  shop_id      city
# 0   !Якутск Орджоникидзе, 56 фран        0   !Якутск
# 1   !Якутск ТЦ "Центральный" фран        1   !Якутск
# 2                Адыгея ТЦ "Мега"        2    Адыгея
# 3  Балашиха ТРК "Октябрь-Киномир"        3  Балашиха
# 4        Волжский ТЦ "Волга Молл"        4  Волжский

# %%
# '!' 문자가 포함된 지명과 포함되지 않은 지명이 중복으로 표기됨. -> 통일시킴
shops.loc[shops.city == '!Якутск', 'city'] = 'Якутск'

# %%
# Интернет-магазин
# Выездная
# 어떻게 처리할지 생각해보기

# %%
city_encoder = LabelEncoder()

shops['city_id'] = city_encoder.fit_transform(shops['city'])
shops = shops[['shop_id', 'city_id']]
shops.head()
# Out:
#    shop_id  city_id
# 0        0       29
# 1        1       29
# 2        2        0
# 3        3        1
# 4        4        2

# %%
shops.city_id.value_counts()
# Out:
# 13    13
# 29     4
# 18     3
# 4      3
# 24     3
# 16     2
# 15     2
# 20     2
# 11     2
# 8      2
# 6      2
# 25     2
# 19     2
# 23     1
# 22     1
# 21     1
# 26     1
# 27     1
# 28     1
# 14     1
# 17     1
# 0      1
# 12     1
# 10     1
# 9      1
# 7      1
# 5      1
# 3      1
# 2      1
# 1      1
# 30     1
# Name: city_id, dtype: int64

# %% [markdown]
# ## 5) test data

# %%
test.head()
# Out:
#    ID  shop_id  item_id
# 0   0        5     5037
# 1   1        5     5320
# 2   2        5     5233
# 3   3        5     5232
# 4   4        5     5268

# %%
test.shape
# Out:
# (214200, 3)

# %%
# test 데이터에서 shop_id는 42개
len(test.shop_id.unique())
# Out:
# 42

# %%
# test 데이터에는 있지만 sales 데이터에는 없는 item_id가 총 363개 있다.
# 363개의 item_id에 대한 판매량은 0으로 예측
len(set(test.item_id) - set(sales.item_id))
# Out:
# 363

# %% [markdown]
# ## 6) 데이터 merge

# %% [markdown]
# ### revenue 컬럼 생성

# %%
sales.head()
# Out:
#         date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0 2013-01-02               0       59    22154      999.00           1.0
# 1 2013-01-03               0       25     2552      899.00           1.0
# 3 2013-01-06               0       25     2554     1709.05           1.0
# 4 2013-01-15               0       25     2555     1099.00           1.0
# 5 2013-01-10               0       25     2564      349.00           1.0

# %%
# 총 수익
sales['revenue'] = sales['item_price'] * sales['item_cnt_day']
sales.head()
# Out:
#         date  date_block_num  shop_id  ...  item_price  item_cnt_day  revenue
# 0 2013-01-02               0       59  ...      999.00           1.0   999.00
# 1 2013-01-03               0       25  ...      899.00           1.0   899.00
# 3 2013-01-06               0       25  ...     1709.05           1.0  1709.05
# 4 2013-01-15               0       25  ...     1099.00           1.0  1099.00
# 5 2013-01-10               0       25  ...      349.00           1.0   349.00
#
# [5 rows x 7 columns]

# %% [markdown]
# ### matrix 데이터프레임 생성 및 컬럼추가
# - 월별(date_block_num), 상점별(shop_id), 아이템별(item_id)
# - city_id, item_category_id, type_id 컬럼추가(merge)

# %%
ts = time.time() # 코드 시작 시간
matrix = []
cols = ['date_block_num', 'shop_id', 'item_id'] # 월별, 상점별, 아이템별

for i in range(34):
    sales_df = sales[sales.date_block_num == i]
    matrix.append(np.array(list(itertools.product([i], 
                    sales_df.shop_id.unique(), sales_df.item_id.unique())),
                    dtype='int16'))
matrix = pd.DataFrame(np.vstack(matrix), columns=cols)

# int8 -> Byte (-128 to 127), int16 -> Integer (-32768 to 32767)
matrix['date_block_num'] = matrix['date_block_num'].astype(np.int8)
matrix['shop_id'] = matrix['shop_id'].astype(np.int8)
matrix['item_id'] = matrix['item_id'].astype(np.int16)

matrix.sort_values(cols, inplace=True)
time.time()-ts # 코드 실행 시간

# itertools.product : 중복 순열
# 월별, 상점별, 아이템별로 모든 가능한 조합을 나타낸다.
# vstack : 이 조합들을 월 순서대로 행 아래에 더해준다.
# Out:
# 15.41308856010437

# %%
matrix.head()
# Out:
#         date_block_num  shop_id  item_id
# 139168               0        0       19
# 141406               0        0       27
# 144881               0        0       28
# 142572               0        0       29
# 138861               0        0       32

# %%
matrix = pd.merge(matrix, shops, on=['shop_id'], how='left') # 'city_id' 추가 됨
matrix= pd.merge(matrix, items, on=['item_id'], how='left')
matrix= pd.merge(matrix, item_categories, on=['item_category_id'], how='left') # 'item_category_id', 'type_id' 추가 됨

# 결과적으로 위의 matrix1 데이터에 3개 컬럼 추가

# %%
matrix.head()
# Out:
#    date_block_num  shop_id  item_id  city_id  item_category_id  type_id
# 0               0        0       19       29                40       11
# 1               0        0       27       29                19        5
# 2               0        0       28       29                30        8
# 3               0        0       29       29                23        5
# 4               0        0       32       29                40       11

# %% [markdown]
# - 월별 매출액(item_cnt_day)데이터 생성 및 matrix 데이터프레임에 merge

# %%
# 월별 매출액
# 월별, 상점별, 아이템별을 그룹화 하고, 일별 판매 개수('item_cnt_day')를 더해줌
group = sales.groupby(['date_block_num', 'shop_id', 'item_id']).agg({'item_cnt_day': ['sum']})
group.head()
# Out:
#                                item_cnt_day
#                                         sum
# date_block_num shop_id item_id
# 0              0       32               6.0
#                        33               3.0
#                        35               1.0
#                        43               1.0
#                        51               2.0

# %%
group.columns = ['item_cnt_month']
group.reset_index(inplace=True)
group.head()
# Out:
#    date_block_num  shop_id  item_id  item_cnt_month
# 0               0        0       32             6.0
# 1               0        0       33             3.0
# 2               0        0       35             1.0
# 3               0        0       43             1.0
# 4               0        0       51             2.0

# %%
# matrix 에 gorup데이터 merge 하여 컬럼을 붙임('item_cnt_month')
matrix = pd.merge(matrix, group, how='left')
matrix.head()
# NaN 값은 판매 개수가 없다고 판단 -> 0으로 처리??
# Out:
#    date_block_num  shop_id  item_id  ...  item_category_id  type_id  item_cnt_month
# 0               0        0       19  ...                40       11             NaN
# 1               0        0       27  ...                19        5             NaN
# 2               0        0       28  ...                30        8             NaN
# 3               0        0       29  ...                23        5             NaN
# 4               0        0       32  ...                40       11             6.0
#
# [5 rows x 7 columns]

# %%
# 결측값을 어떻게 처리 할 지 생각해보기!!!
# 일단 0으로 처리
matrix['item_cnt_month'] = (matrix['item_cnt_month'].fillna(0).astype(np.float16))
matrix.head()
# Out:
#    date_block_num  shop_id  item_id  ...  item_category_id  type_id  item_cnt_month
# 0               0        0       19  ...                40       11             0.0
# 1               0        0       27  ...                19        5             0.0
# 2               0        0       28  ...                30        8             0.0
# 3               0        0       29  ...                23        5             0.0
# 4               0        0       32  ...                40       11             6.0
#
# [5 rows x 7 columns]

# %% [markdown]
# - decjan 컬럼 생성 및 matrix 데이터프레임에 merge
#   - 판매량이 많은 연말과 연초 (12월, 1월) -> 1 / 나머지는 0으로 변환

# %%
# 월 별 총 판매개수
group1 = sales.groupby(by=['date_block_num']).sum()
group1 = group1.reset_index()
group1.head()
# Out:
#    date_block_num  shop_id  ...  item_cnt_day       revenue
# 0               0  3405258  ...      131849.0  9.239894e+07
# 1               1  3102452  ...      128382.0  9.096449e+07
# 2               2  4006652  ...      147438.0  1.052654e+08
# 3               3  3157303  ...      107439.0  6.945713e+07
# 4               4  3087675  ...      107147.0  6.525317e+07
#
# [5 rows x 6 columns]

# %%
plt.figure(figsize=(12,3))
plt.plot(group1.date_block_num,  group1.item_cnt_day)
plt.show()

# %%
# 연말(12월), 연초(1월)에 판매량이 많은 것으로 확인
# 12월,1월 -> 1 / 나머지 -> 0 으로 변환하여 decjan 컬럼생성

# %%
matrix['decjan'] = np.where(matrix['date_block_num'].isin([11,12,23,24]), 1,0)
matrix.head()
# Out:
#    date_block_num  shop_id  item_id  ...  type_id  item_cnt_month  decjan
# 0               0        0       19  ...       11             0.0       0
# 1               0        0       27  ...        5             0.0       0
# 2               0        0       28  ...        8             0.0       0
# 3               0        0       29  ...        5             0.0       0
# 4               0        0       32  ...       11             6.0       0
#
# [5 rows x 8 columns]

# %%
# decjan 확인하기
print(len(matrix.loc[matrix['date_block_num'] == 11,:]))
print(len(matrix.loc[matrix['date_block_num'] == 12,:]))
print(len(matrix.loc[matrix['date_block_num'] == 23,:]))
print(len(matrix.loc[matrix['date_block_num'] == 24,:]))
# Out:
# 389712
# 347116
# 330000
# 306800

# %%
389712+347116+330000+306800
# Out:
# 1373628

# %%
(matrix['decjan'] == 1).sum()  # 1373628

# 합이 동일하므로 올바르게 변환됨을 확인
# Out:
# 1373628

# %% [markdown]
# - shop_cnt_month (shop별 월 평균 판매수량) 데이터 생성 및 matrix 데이터프레임에 merge

# %%
# 월별 shop별 평균 판매 수량(shop_cnt_month) 
group2 = matrix.groupby(['date_block_num', 'shop_id']).agg({'item_cnt_month': ['sum']})
group2.columns = ['shop_cnt_month']
group2.reset_index(inplace=True)

# %%
group2.head()
# Out:
#    date_block_num  shop_id  shop_cnt_month
# 0               0        0          5576.0
# 1               0        1          2948.0
# 2               0        2          1151.0
# 3               0        3           767.0
# 4               0        4          2116.0

# %%
matrix = pd.merge(matrix, group2, on=['date_block_num', 'shop_id'], how='left')
matrix.head()
# Out:
#    date_block_num  shop_id  item_id  ...  item_cnt_month  decjan  shop_cnt_month
# 0               0        0       19  ...             0.0       0          5576.0
# 1               0        0       27  ...             0.0       0          5576.0
# 2               0        0       28  ...             0.0       0          5576.0
# 3               0        0       29  ...             0.0       0          5576.0
# 4               0        0       32  ...             6.0       0          5576.0
#
# [5 rows x 9 columns]

# %%
# matrix 원본 카피
matrix1 = matrix.copy()
matrix1.head()
# Out:
#    date_block_num  shop_id  item_id  ...  item_cnt_month  decjan  shop_cnt_month
# 0               0        0       19  ...             0.0       0          5576.0
# 1               0        0       27  ...             0.0       0          5576.0
# 2               0        0       28  ...             0.0       0          5576.0
# 3               0        0       29  ...             0.0       0          5576.0
# 4               0        0       32  ...             6.0       0          5576.0
#
# [5 rows x 9 columns]

# %% [markdown]
# ### 첫번째 판매 후 지난 개월수 데이터 생성 및 matrix에 merge
# - item_shop_fisrst_sale, item_first_sale

# %%
# 마지막 판매가 있고 나서부터 지난 개월 수 -> 추세 파악을 위해 먼저 이 코드 실행
# shop-item 별

cache = {}
matrix1['item_shop_last_sale'] = -1
matrix1['item_shop_last_sale'] = matrix1['item_shop_last_sale'].astype(np.int8)

for index, row in matrix1.iterrows():
    key = str(row.item_id) + ' ' + str(row.shop_id)
    if key not in cache:
        if row.item_cnt_month != 0:
            cache[key] = row.date_block_num
    else:
        last_date_block_num = cache[key]
        matrix1.at[index, 'item_shop_last_sale'] = row.date_block_num - last_date_block_num
        cache[key] = row.date_block_num
# 20분 걸림

# %%
# item별
cache = {}
matrix1['item_last_sale'] = -1
matrix1['item_last_sale'] = matrix1['item_last_sale'].astype(np.int8)

for index, row in matrix1.iterrows():
    key = row.item_id
    if key not in cache:
        if row.item_cnt_month != 0:
            cache[key] = row.date_block_num
    else:
        last_date_block_num = cache[key]
        if row.date_block_num > last_date_block_num:
            matrix1.at[index, 'item_last_sale'] = row.date_block_num - last_date_block_num
            cache[key] = row.date_block_num

# 15분 걸림

# %%
#첫번째 판매 후 지난 개월 수 (shop-item pair, item pair 별)

matrix1.groupby(['item_id','shop_id'])['date_block_num']
matrix1['date_block_num'] - matrix1.groupby(['item_id', 'shop_id'])['date_block_num'].transform('min')
# Out:
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
#             ..
# 10884455    15
# 10884456     2
# 10884457     8
# 10884458    24
# 10884459    25
# Name: date_block_num, Length: 10884460, dtype: int8

# %%
matrix1['item_shop_first_sale'] = matrix1['date_block_num'] - matrix1.groupby(['item_id', 'shop_id'])['date_block_num'].transform('min')
matrix1['item_first_sale'] = matrix1['date_block_num'] - matrix1.groupby('item_id')['date_block_num'].transform('min')
matrix1.head()
# Out:
#    date_block_num  shop_id  item_id  city_id  item_category_id  type_id  \
# 0               0        0       19        0                40       11
# 1               0        0       27        0                19        5
# 2               0        0       28        0                30        8
# 3               0        0       29        0                23        5
# 4               0        0       32        0                40       11
#
#    item_cnt_month  decjan  shop_cnt_month  item_shop_last_sale  \
# 0             0.0       0          5576.0                   -1
# 1             0.0       0          5576.0                   -1
# 2             0.0       0          5576.0                   -1
# 3             0.0       0          5576.0                   -1
# 4             6.0       0          5576.0                   -1
#
#    item_last_sale  item_shop_first_sale  item_first_sale
# 0              -1                     0                0
# 1              -1                     0                0
# 2              -1                     0                0
# 3              -1                     0                0
# 4              -1                     0                0

# %% [markdown]
# # 2. EDA

# %% [markdown]
# ### 1) 월별 거래수

# %%
#월별 거래수
sales.groupby('date_block_num').count()
sales.groupby('date_block_num')['date'].count()

transactions = sales.groupby('date_block_num')['date'].count()
transactions

plt.style.use('ggplot')
transactions.plot(title = 'number of transactions of month', color = 'black')
plt.show()

# %% [markdown]
# 전체적으로 월별 거래수가 꾸준히 하락함
# 엄청 높게 치솟는 두 개 점은 연말(13년 12월, 14년 12월)임

# %% [markdown]
# ### 2) 월별 거래된 shops 수, 월별 거래된 items 수

# %%
# 각 월 블록에서 매출 데이터에 거래가 있는 고유 상점 및 품목 수
shop_count = sales.groupby('date_block_num')['shop_id'].nunique()
item_count = sales.groupby('date_block_num')['item_id'].nunique()

sales.groupby('date_block_num').nunique()
#sales.groupby('date_block_num')['shop_id'].nunique() # 월별 고유 상점수
#sales.groupby('date_block_num')['item_id'].nunique()  # 월별 고유 아이템수

sales['item_id'].nunique() #item 21802개
items['item_id'].nunique() #item 22170개
#sales['shop_id'].nunique() #shop 60개
shops['shop_id'].nunique() #shop 60개
# Out:
# 60

# %% [markdown]
# sales에 있는 item_id랑 items에 있는 item_id의 수가 다름

# %%
fig, ax = plt.subplots(1,2, figsize = (12,5))
shop_count.plot(ax = ax[0], color = 'red')
item_count.plot(ax = ax[1], color = 'blue')
ax[0].set_title('number of shops with transactions') #거래가 있는 상점수
ax[1].set_title('number of items with transactions') #거래된 아이템수
plt.show()

# %% [markdown]
# 연말을 제외하고는 월별 거래수와 월별 거래된 아이템수 모두 하락세
# 거래처들의 수는 2년차부터는 느는 듯 했으나 2말부터 훅훅 떨어짐
# 그리고 거래처수가 60개로 나오는데 차트를 보면 매달 모든 가게에서 거래되는 게 아니고 물건도 많이 못미침

# %% [markdown]
# ### 3) 상점별 하루 item 판매개수

# %%
shop_ns = sales[['shop_id','item_cnt_day']]
shop_ns.set_index(['shop_id'])
shop_ns = shop_ns.groupby(by=['shop_id']).sum()
shop_ns.plot(kind = 'bar')
plt.show()

# %% [markdown]
# ### 4) 가격별 item 하루 판매개수

# %%
price_ns = sales[['item_price','item_cnt_day']]
price_ns = price_ns.groupby(by=['item_price']).sum()
plt.plot(price_ns.index, price_ns.values)
plt.xlabel('item_price')
plt.ylabel('item_cnt_day')
plt.show()

# %% [markdown]
# ### 5) 월별 총 판매금액

# %%
# 월별 총 판매금액
time_ns = sales[['item_price','date_block_num']]
time_ns = time_ns.groupby(by=['date_block_num']).sum()
plt.figure(figsize=(12,3))
plt.plot(time_ns.index, time_ns.values)
plt.show()

# %% [markdown]
# ### 6) 월별 총 판매개수

# %%
# 월별 총 판매개수
group1 = sales.groupby(by=['date_block_num']).sum()
group1 = group1.reset_index()
plt.figure(figsize=(12,3))
plt.plot(group1.date_block_num,  group1.item_cnt_day)
plt.show()

# %% [markdown]
# ### 7) 품목별 판매량

# %%
sales1= pd.merge(sales, items, on=['item_id'], how='left')
sales1= pd.merge(sales1, item_categories, on=['item_category_id'], how='left')
sales1.head()
# Out:
#         date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0 2013-01-02               0       59    22154      999.00           1.0
# 1 2013-01-03               0       25     2552      899.00           1.0
# 2 2013-01-06               0       25     2554     1709.05           1.0
# 3 2013-01-15               0       25     2555     1099.00           1.0
# 4 2013-01-10               0       25     2564      349.00           1.0
#
#    revenue  item_category_id  type_id
# 0   999.00                37       11
# 1   899.00                58       13
# 2  1709.05                58       13
# 3  1099.00                56       13
# 4   349.00                59       13

# %%
# 품목별 판매량 
Category_sum=sales1.groupby(['item_category_id'], as_index=False)['item_cnt_day'].sum()
fig, axes = plt.subplots(1,1,figsize = (35,8))
sns.barplot(x="item_category_id",y="item_cnt_day", data=Category_sum)
plt.show()

# %%
# 카테고리별 판매금액
Category_sum=sales1.groupby(['item_category_id'], as_index=False)['revenue'].sum()
fig, axes = plt.subplots(1,1,figsize = (35,8))
sns.barplot(x="item_category_id",y="revenue", data=Category_sum)
plt.show()

# %%
sales1['year'] = sales1['date'].dt.year
sales1['month'] = sales1['date'].dt.month
sales1.head()
# Out:
#         date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0 2013-01-02               0       59    22154      999.00           1.0
# 1 2013-01-03               0       25     2552      899.00           1.0
# 2 2013-01-06               0       25     2554     1709.05           1.0
# 3 2013-01-15               0       25     2555     1099.00           1.0
# 4 2013-01-10               0       25     2564      349.00           1.0
#
#    revenue  item_category_id  type_id  year  month
# 0   999.00                37       11  2013      1
# 1   899.00                58       13  2013      1
# 2  1709.05                58       13  2013      1
# 3  1099.00                56       13  2013      1
# 4   349.00                59       13  2013      1

# %%
#연도별 판매량  -> Year, Month 컬럼 만든 후 확인 가능합니다(이재호)
fig,axes = plt.subplots(1,1,figsize=(7,7))
sns.lineplot(x=sales1['year'],y=sales1['item_cnt_day'])
plt.show()

# %%
# 월별 판매량
fig,axes = plt.subplots(1,1,figsize=(7,7))
sns.lineplot(x=sales1['month'],y=sales1['item_cnt_day'])
plt.show()

# %%
# 연도별 판매총액 >> 14년 까진 꾸준하다가 14년부터 판매량 감소
fig,axes = plt.subplots(1,1,figsize=(7,7))
sns.lineplot(x=sales1['year'],y=sales1['revenue'])
plt.show()

# %%
# 상점별 월 item 판매개수 -> 월 별 item 판매개수 컬럼 만든 후 확인 가능합니다.(김홍비)
shop_ns = matrix[['shop_id','item_cnt_month']]
shop_ns.set_index(['shop_id'])
shop_ns = shop_ns.groupby(by=['shop_id']).sum()
shop_ns.plot(kind = 'bar')
plt.xlabel('shop_id')
plt.ylabel('item_cnt_month')
plt.show()

# %%
# 카테고리별 판매개수
category_ns = matrix[['item_category_id','item_cnt_month']]
category_ns.set_index(['item_category_id'])
category_ns = category_ns.groupby(by=['item_category_id']).sum()
category_ns.plot(kind = 'bar')
plt.xlabel('category_id')
plt.ylabel('item_cnt_month')
plt.show()

# %%
# 도시별 판매개수
city_ns = matrix[['city_id','item_cnt_month']]
city_ns.set_index(['city_id'])
city_ns = city_ns.groupby(by=['city_id']).sum()
city_ns.plot(kind = 'bar')
plt.xlabel('city_id')
plt.ylabel('item_cnt_month')
plt.show()

# %%
# 동일한 item의 shop별 가격차이
sales_temp = sales[sales['shop_id'] == 31][['date','item_id','item_price']].reset_index(drop=True)
items_list = sales_temp['item_id'].unique()[0:8]

fig, axes = plt.subplots(1,1, figsize=(25,8))
colors = ['red','orange','blue','green','yellow','purple','cyan','brown']
for i, item in enumerate(items_list):
    dprice = sales_temp[sales_temp['item_id'] == item][['item_price','date']]
    
    sns.lineplot(x=dprice['date'], y=dprice['item_price'], ax=axes, color=colors[i], label=item)
    
axes.set_title('Price development of items - shop_id 31',fontsize="28")
axes.legend()
plt.show()


sales_temp = sales[sales['shop_id'] == 28][['date','item_id','item_price']].reset_index(drop=True)
items_list = sales_temp['item_id'].unique()[0:8]

fig, axes = plt.subplots(1,1, figsize=(25,8))
colors = ['red','orange','blue','green','yellow','purple','cyan','brown']
for i, item in enumerate(items_list):
    dprice = sales_temp[sales_temp['item_id'] == item][['item_price','date']]
    
    sns.lineplot(x=dprice['date'], y=dprice['item_price'], ax=axes, color=colors[i], label=item)
    
axes.set_title('Price development of items - shop_id 28',fontsize="28")
axes.legend()
plt.show()


sales_temp = sales[sales['shop_id'] == 21][['date','item_id','item_price']].reset_index(drop=True)
items_list = sales_temp['item_id'].unique()[0:8]

fig, axes = plt.subplots(1,1, figsize=(25,8))
colors = ['red','orange','blue','green','yellow','purple','cyan','brown']
for i, item in enumerate(items_list):
    dprice = sales_temp[sales_temp['item_id'] == item][['item_price','date']]
    
    sns.lineplot(x=dprice['date'], y=dprice['item_price'], ax=axes, color=colors[i], label=item)
    
axes.set_title('Price development of items - shop_id 21',fontsize="28")
axes.legend()
plt.show()

# %% [markdown]
# ### [ 환불 적용 모듈 ]

# %%
train_F = sales.copy()
k = train_F[train_F.item_cnt_day < 0]
qwe = 0
minimum = 0
timefunc = time.time()
for i in range(len(k)):
    try:
        if k.iloc[i,5] < minimum:
            minimum = k.iloc[i,5]
        a = (train_F[np.array(train_F.item_id == k.iloc[i,3]) & np.array(train_F.shop_id == k.iloc[i,2])])
        if a.date.min() < k.iloc[i,0]:
            h = a[a.date==a.date[a.date < k.iloc[i,0]].max()].index[0]
            qwe += 1
            train_F.loc[h,'item_cnt_day'] += k.iloc[i,5]
#            if qwe == 5:
#                break
        else:
            pass
    except:
        pass
train_F.drop(k.index,axis = 0,inplace = True)
print(len(k))
print('필요 없는 값:',(len(k) - qwe))
print('적용한 값의 수::',qwe)
print(minimum)
print(time.time() - timefunc)

# %% [markdown]
# #### 환불적용코드 수정 3배빠름

# %%
train_F = sales.copy()
k = train_F[train_F.item_cnt_day < 0]
timefunc = time.time()
for i in range(len(k)):
    try:
        a = (train_F[(train_F.item_id == k.iloc[i,3]) & (train_F.shop_id == k.iloc[i,2])])
        if a.date.min() < k.iloc[i,0]:
            h = a[(a.date==a.date[a.date < k.iloc[i,0]].max())].index[0]
            print(h)
            if train_F.loc[h,'item_cnt_day'] > abs(k.iloc[i,5]):
                train_F.loc[h,'item_cnt_day'] += k.iloc[i,5]
        else:
            pass
    except:
        pass
train_F.drop(train_F[train_F.item_cnt_day < 0].index, axis = 0,inplace = True)
print(time.time() - timefunc)
train_F
# Out:
# 1
# 147
# 174
# 809
# 863596
# 1744
# 1834
# 585183
# 3385
# 3430
# 156634
# 3531
# 3755
# 4308
# 986923
# 4798
# 4926
# 4949
# 5150
# 5504
# 7138
# 7173
# 7276
# 380030
# 516424
# 8199
# 8500
# 983992
# 9480
# 159379
# 10091
# 515655
# 10894
# 289510
# 13633
# 308044
# 15197
# 539175
# 17182
# 17572
# 806833
# 540531
# 540610
# 18550
# 18878
# 966743
# 19788
# 21508
# 23060
# 23218
# 23267
# 23388
# 23813
# 24503
# 815715
# 27270
# 27392
# 28114
# 29007
# 30335
# 32464
# 945828
# 671704
# 32778
# 1010442
# 870235
# 35640
# 1071495
# 35810
# 36309
# 36985
# 37129
# 37328
# 37374
# 172700
# 832002
# 45401
# 45417
# 46004
# 687278
# 385389
# 46752
# 665930
# 151367
# 148183
# 49147
# 279102
# 146556
# 50019
# 144978
# 799412
# 51336
# 52110
# 55631
# 148065
# 57782
# 175800
# 58422
# 58587
# 58662
# 1058396
# 58986
# 58987
# 59026
# 59116
# 836635
# 59156
# 59157
# 175577
# 59161
# 59198
# 59197
# 189648
# 61590
# 62042
# 63470
# 947751
# 238977
# 63505
# 64818
# 477067
# 477045
# 66250
# 963777
# 66676
# 67365
# 67517
# 67620
# 68533
# 247700
# 1043334
# 70793
# 70892
# 413086
# 71977
# 239815
# 886323
# 72896
# 73138
# 73472
# 73964
# 74162
# 74379
# 601007
# 75022
# 600843
# 407519
# 1202232
# 76066
# 76537
# 76739
# 504740
# 77652
# 78067
# 736722
# 343709
# 133736
# 79105
# 79391
# 79586
# 79564
# 79664
# 79857
# 1091088
# 708196
# 80267
# 1023087
# 80605
# 80957
# 80845
# 80856
# 136502
# 842760
# 257615
# 81734
# 81776
# 142019
# 82385
# 83930
# 84973
# 85739
# 85860
# 86129
# 86265
# 490455
# 700968
# 86729
# 768420
# 87469
# 88201
# 88589
# 88595
# 88719
# 89066
# 89243
# 839313
# 90711
# 939640
# 93225
# 93284
# 93466
# 265600
# 93577
# 93599
# 93978
# 94199
# 94460
# 94663
# 724805
# 95124
# 95174
# 95355
# 96354
# 96654
# 96659
# 96880
# 256164
# 97261
# 97567
# 138291
# 98008
# 98078
# 495106
# 98422
# 99050
# 99675
# 102740
# 103090
# 103464
# 103546
# 893503
# 103975
# 104051
# 196012
# 104646
# 105158
# 105206
# 105809
# 228448
# 105980
# 106463
# 781325
# 229452
# 107149
# 107193
# 107531
# 107550
# 547046
# 202518
# 849483
# 109126
# 110167
# 1113693
# 110199
# 1106463
# 110801
# 234227
# 111484
# 716689
# 549280
# 112060
# 113147
# 113263
# 113363
# 468874
# 115354
# 429212
# 90967
# 116651
# 116947
# 117349
# 117528
# 117567
# 117657
# 117664
# 117773
# 119992
# 120127
# 120526
# 122715
# 123084
# 123239
# 123368
# 471747
# 124525
# 114658
# 124611
# 124699
# 125969
# 125984
# 126241
# 126826
# 126811
# 715149
# 852757
# 129405
# 263139
# 129942
# 130143
# 130220
# 130538
# 85334
# 962650
# 84756
# 75955
# 132204
# 1099875
# 132338
# 78214
# 132917
# 133257
# 133520
# 133723
# 134192
# 134209
# 134808
# 80200
# 254779
# 135758
# 1094026
# 136152
# 136202
# 136395
# 136413
# 136442
# 136697
# 137023
# 83760
# 137863
# 138843
# 138856
# 139456
# 86511
# 87451
# 85066
# 140706
# 141066
# 141346
# 928988
# 141815
# 142056
# 82236
# 142202
# 131411
# 142802
# 142857
# 1082228
# 282996
# 143834
# 144061
# 144224
# 145019
# 145744
# 300020
# 147897
# 148024
# 148155
# 513587
# 149490
# 148210
# 149969
# 150319
# 48343
# 151692
# 151917
# 152071
# 152966
# 153224
# 153608
# 154030
# 154212
# 354899
# 155258
# 155886
# 683721
# 157219
# 157501
# 288769
# 8448
# 158153
# 11160
# 159304
# 9727
# 289723
# 159927
# 160038
# 160578
# 161177
# 161918
# 13927
# 13964
# 13920
# 162792
# 162834
# 162844
# 163020
# 163343
# 163929
# 164063
# 164250
# 164596
# 164808
# 165230
# 166977
# 166987
# 167123
# 341838
# 168043
# 168765
# 295373
# 31356
# 171935
# 36764
# 871247
# 871259
# 1011957
# 174057
# 881763
# 59162
# 836271
# 175691
# 175698
# 662438
# 175714
# 370150
# 884796
# 836942
# 176641
# 885424
# 184082
# 185242
# 185884
# 186013
# 186422
# 186461
# 186888
# 249678
# 187463
# 187669
# 67179
# 188019
# 188025
# 188591
# 188937
# 189240
# 190306
# 190722
# 476904
# 558066
# 192305
# 192463
# 62937
# 192836
# 947132
# 947131
# 1056027
# 193583
# 193697
# 193706
# 193745
# 194002
# 194069
# 113252
# 194531
# 194969
# 899902
# 195833
# 237402
# 197810
# 198195
# 198638
# 199567
# 199574
# 199789
# 201250
# 201573
# 230118
# 201825
# 439406
# 108738
# 202822
# 202948
# 203214
# 718389
# 203711
# 24173
# 204790
# 204878
# 205004
# 205969
# 206125
# 206270
# 206330
# 206553
# 207336
# 208902
# 208988
# 320604
# 209597
# 210587
# 318877
# 211031
# 211175
# 212358
# 330685
# 213633
# 214461
# 214483
# 214521
# 215494
# 216325
# 217293
# 217295
# 424954
# 217756
# 217959
# 217986
# 217995
# 218435
# 218441
# 218445
# 218602
# 219686
# 220077
# 220082
# 220092
# 220090
# 220498
# 220757
# 27378
# 19324
# 223775
# 463589
# 202307
# 437864
# 226201
# 226355
# 226441
# 193696
# 226680
# 438082
# 225988
# 199677
# 105461
# 228381
# 899157
# 229053
# 897456
# 229441
# 779227
# 202999
# 230725
# 232338
# 232568
# 233103
# 234162
# 474164
# 197587
# 234617
# 234726
# 235082
# 235339
# 235676
# 237080
# 1056765
# 185103
# 191823
# 240134
# 70919
# 1050849
# 242969
# 243921
# 783611
# 244135
# 188945
# 244463
# 245021
# 187087
# 244950
# 245653
# 246038
# 780340
# 246714
# 247738
# 249550
# 252094
# 252169
# 253713
# 140227
# 1095364
# 140538
# 254907
# 254935
# 136353
# 256243
# 256356
# 256405
# 256666
# 253471
# 697479
# 258123
# 258174
# 258433
# 258517
# 259087
# 259200
# 79957
# 259526
# 259702
# 769803
# 259967
# 260149
# 260936
# 262411
# 85361
# 75885
# 262922
# 129880
# 1088614
# 76989
# 264268
# 957443
# 504500
# 126798
# 125637
# 265169
# 117425
# 265499
# 94563
# 265976
# 126492
# 622224
# 266117
# 266124
# 266215
# 266296
# 267304
# 267463
# 267557
# 267831
# 268044
# 268118
# 268117
# 126360
# 94737
# 269910
# 269915
# 269933
# 269965
# 270019
# 270243
# 270245
# 270376
# 270664
# 94234
# 274094
# 275070
# 275830
# 275888
# 275972
# 277379
# 619030
# 279649
# 858431
# 280609
# 280672
# 280880
# 281472
# 282501
# 284846
# 385989
# 285863
# 286264
# 286586
# 287027
# 161062
# 287763
# 288312
# 158217
# 288477
# 288574
# 288728
# 288965
# 289130
# 803843
# 289606
# 290086
# 598699
# 290809
# 292306
# 292638
# 292930
# 293472
# 293554
# 173653
# 293711
# 294542
# 295171
# 1072784
# 580537
# 295705
# 296146
# 170687
# 170681
# 296913
# 36773
# 527152
# 298713
# 147540
# 150240
# 666185
# 301060
# 301668
# 301738
# 370206
# 301844
# 1058071
# 175601
# 302007
# 59133
# 175628
# 302150
# 58338
# 1030735
# 1030188
# 633434
# 308010
# 365486
# 310838
# 311666
# 312714
# 312798
# 313232
# 313329
# 313369
# 82964
# 313813
# 314479
# 314561
# 314755
# 446377
# 317269
# 19773
# 216112
# 317761
# 318249
# 915070
# 1516
# 155874
# 320228
# 321135
# 156793
# 322562
# 322822
# 322799
# 12301
# 323276
# 323481
# 155548
# 324226
# 1016855
# 205798
# 206265
# 326302
# 326442
# 326445
# 326468
# 205431
# 326597
# 326803
# 205264
# 328735
# 329085
# 330550
# 331221
# 331916
# 333609
# 333610
# 333612
# 333803
# 334097
# 334221
# 337205
# 337566
# 337724
# 337744
# 338339
# 338455
# 339122
# 1188751
# 339824
# 339885
# 341292
# 341562
# 342037
# 342050
# 342864
# 77627
# 343495
# 343859
# 343997
# 344205
# 164927
# 989750
# 348075
# 348087
# 329427
# 154269
# 154466
# 351628
# 351915
# 286219
# 352566
# 285839
# 285088
# 352897
# 325213
# 322958
# 354789
# 355191
# 153350
# 790554
# 1073170
# 355327
# 356056
# 356309
# 359393
# 361000
# 361060
# 362862
# 326960
# 905544
# 902729
# 364162
# 364793
# 365035
# 302029
# 58807
# 176092
# 302046
# 511750
# 366840
# 302149
# 302113
# 366920
# 341684
# 369361
# 369370
# 369848
# 302491
# 302492
# 369887
# 302444
# 302372
# 302540
# 302321
# 302177
# 58424
# 370153
# 370157
# 301764
# 370223
# 59029
# 370275
# 301867
# 370289
# 565298
# 370334
# 370355
# 370366
# 661787
# 301885
# 175785
# 175783
# 301861
# 1006763
# 1175574
# 370861
# 371320
# 297343
# 371626
# 872833
# 373533
# 171956
# 375613
# 376485
# 376861
# 377095
# 48993
# 378412
# 378625
# 161961
# 857199
# 158443
# 379180
# 854412
# 380209
# 299666
# 298442
# 383179
# 52248
# 384785
# 798701
# 282196
# 831722
# 282023
# 975726
# 387772
# 843884
# 86930
# 488357
# 256807
# 82178
# 392511
# 257627
# 393040
# 393168
# 393416
# 264914
# 394043
# 394216
# 267309
# 394973
# 395254
# 395246
# 395856
# 723363
# 396821
# 839345
# 90774
# 994673
# 400665
# 400892
# 337860
# 336917
# 337096
# 402419
# 338282
# 338243
# 336181
# 734403
# 403629
# 403639
# 403925
# 404020
# 332105
# 405472
# 405498
# 406307
# 263112
# 408229
# 408382
# 408442
# 410369
# 410398
# 410461
# 411029
# 411739
# 411961
# 412407
# 415515
# 240495
# 62689
# 416526
# 416764
# 245656
# 561342
# 417653
# 417818
# 418060
# 419767
# 419776
# 419842
# 419953
# 421311
# 421423
# 421462
# 20128
# 421704
# 445951
# 422555
# 60321
# 423513
# 424037
# 243382
# 241717
# 241514
# 661246
# 426814
# 426936
# 236571
# 428546
# 269402
# 429970
# 268172
# 431128
# 431571
# 431882
# 432343
# 433185
# 433513
# 228939
# 227982
# 199813
# 467862
# 434398
# 434402
# 435303
# 247765
# 561892
# 106600
# 436371
# 195548
# 745297
# 437836
# 225485
# 225505
# 901118
# 229774
# 438634
# 358335
# 632369
# 440587
# 440934
# 539940
# 442957
# 29367
# 364460
# 316304
# 451554
# 597794
# 452623
# 452867
# 1079585
# 455099
# 1086007
# 352600
# 458741
# 905722
# 458830
# 458821
# 458894
# 645019
# 459901
# 681256
# 462231
# 746784
# 464578
# 464947
# 465144
# 107910
# 466027
# 1049158
# 466488
# 466646
# 466794
# 467589
# 438788
# 426790
# 231952
# 468857
# 468910
# 115642
# 469075
# 469988
# 470265
# 470367
# 470799
# 115497
# 123295
# 714798
# 472314
# 473849
# 474060
# 240840
# 475901
# 476180
# 426251
# 66643
# 478049
# 478421
# 479965
# 480082
# 480087
# 480089
# 480279
# 481756
# 484744
# 184157
# 485801
# 485858
# 485853
# 390241
# 756762
# 1094228
# 625097
# 487798
# 257505
# 131666
# 490358
# 490534
# 139085
# 490709
# 970457
# 494691
# 630690
# 975586
# 495205
# 138494
# 843592
# 120003
# 333397
# 992314
# 1213987
# 1099394
# 609734
# 132513
# 77658
# 403334
# 402854
# 500623
# 501142
# 501273
# 614488
# 502376
# 502622
# 502748
# 502954
# 503447
# 603842
# 134593
# 504758
# 505753
# 771166
# 506370
# 506511
# 507598
# 508241
# 151243
# 509793
# 509798
# 382964
# 509985
# 283042
# 381699
# 565459
# 302020
# 511745
# 366802
# 511968
# 830363
# 513353
# 515914
# 516265
# 686673
# 684584
# 518645
# 519150
# 519573
# 520533
# 520580
# 520651
# 520660
# 521250
# 265792
# 521556
# 622709
# 522858
# 523353
# 524156
# 524359
# 524843
# 395438
# 525072
# 339418
# 525171
# 525181
# 525202
# 525235
# 525366
# 525912
# 526502
# 526989
# 295859
# 375824
# 219031
# 533560
# 533863
# 909691
# 947930
# 536057
# 536061
# 477474
# 242686
# 425129
# 217455
# 537191
# 781780
# 540923
# 541095
# 1034411
# 541519
# 543575
# 543778
# 544172
# 545665
# 545859
# 545957
# 546112
# 546191
# 546661
# 468120
# 548838
# 548915
# 124961
# 550035
# 550726
# 473892
# 552793
# 886201
# 1234775
# 555050
# 417216
# 555188
# 556547
# 238583
# 558556
# 650869
# 558724
# 434593
# 559733
# 107221
# 560734
# 561092
# 561834
# 562117
# 562446
# 563453
# 509163
# 298614
# 299073
# 176642
# 512036
# 370154
# 837074
# 565655
# 565828
# 565834
# 511764
# 511504
# 567820
# 568143
# 568187
# 568282
# 1023463
# 570346
# 382425
# 665539
# 833072
# 571197
# 571673
# 571708
# 572299
# 572540
# 670443
# 573491
# 574767
# 574806
# 946576
# 825056
# 576192
# 576664
# 577119
# 577309
# 577620
# 578232
# 870089
# 579931
# 530630
# 1166890
# 462046
# 584712
# 585308
# 587058
# 458791
# 588138
# 904607
# 457310
# 458716
# 590407
# 591353
# 591371
# 9972
# 1178085
# 678602
# 279635
# 689682
# 594353
# 280702
# 146928
# 595661
# 452105
# 596246
# 596737
# 596886
# 598195
# 598390
# 679631
# 599087
# 855772
# 599645
# 599699
# 600109
# 600294
# 352140
# 600379
# 600531
# 600676
# 601223
# 603247
# 603585
# 603628
# 79655
# 603892
# 604093
# 604147
# 604361
# 604810
# 400705
# 497993
# 610675
# 610845
# 611082
# 611775
# 612070
# 612226
# 501148
# 612763
# 613169
# 613497
# 613673
# 613676
# 613680
# 613753
# 613759
# 613937
# 614480
# 614791
# 615202
# 710390
# 1208400
# 617943
# 618554
# 492082
# 620085
# 395382
# 939385
# 622582
# 622735
# 623049
# 524832
# 728445
# 624955
# 625151
# 625895
# 697196
# 627828
# 255512
# 630736
# 630892
# 632054
# 364385
# 635814
# 636138
# 636184
# 636536
# 638267
# 638489
# 638570
# 360606
# 319086
# 643408
# 645856
# 646167
# 646422
# 648148
# 885534
# 649748
# 558875
# 650716
# 558948
# 558940
# 651459
# 651484
# 188149
# 654167
# 654428
# 654447
# 312236
# 1032951
# 655627
# 656214
# 656529
# 656890
# 657417
# 658485
# 60378
# 658758
# 659231
# 659289
# 659816
# 659905
# 661324
# 565525
# 565361
# 301872
# 661800
# 1059411
# 565689
# 511970
# 836283
# 566226
# 662347
# 151284
# 666163
# 666319
# 666600
# 666554
# 667179
# 668630
# 573072
# 670453
# 1065731
# 670683
# 374783
# 671134
# 671137
# 671237
# 671495
# 671596
# 671802
# 671804
# 672541
# 672542
# 523310
# 673083
# 673228
# 673819
# 674085
# 674091
# 531351
# 171927
# 675701
# 676247
# 855982
# 677650
# 678317
# 679256
# 679986
# 681884
# 682596
# 682696
# 52173
# 685809
# 685836
# 685894
# 686182
# 798681
# 687302
# 687512
# 10569
# 694195
# 694361
# 694368
# 694995
# 695267
# 263813
# 695938
# 696384
# 696504
# 697086
# 697199
# 697609
# 136110
# 698384
# 700234
# 627716
# 701172
# 702205
# 703049
# 703271
# 703309
# 703506
# 703627
# 706551
# 602653
# 708364
# 708958
# 412362
# 709493
# 709595
# 709775
# 614221
# 741938
# 742187
# 748545
# 552267
# 552129
# 713975
# 714255
# 714642
# 715058
# 715710
# 739725
# 1047323
# 717459
# 936949
# 438665
# 899517
# 718973
# 719036
# 719090
# 896839
# 720343
# 551893
# 721647
# 722559
# 723567
# 723569
# 723639
# 723703
# 724174
# 724753
# 725572
# 727742
# 727767
# 727974
# 623623
# 430577
# 524371
# 730181
# 616506
# 493351
# 730928
# 731378
# 731971
# 614882
# 497862
# 732755
# 733905
# 733942
# 734023
# 734216
# 734629
# 616193
# 499180
# 736215
# 736462
# 736585
# 737406
# 705122
# 609163
# 738548
# 739043
# 1107925
# 741372
# 741467
# 742766
# 743219
# 744175
# 621173
# 745133
# 746070
# 747510
# 748916
# 895673
# 848298
# 749635
# 750013
# 750160
# 104175
# 750206
# 750655
# 545770
# 750910
# 751113
# 751246
# 95545
# 754413
# 754456
# 487572
# 757334
# 758637
# 759053
# 759788
# 849807
# 760499
# 760710
# 530023
# 762335
# 762651
# 763615
# 764385
# 491214
# 764448
# 764485
# 764477
# 764595
# 253124
# 764718
# 131068
# 691276
# 764991
# 764998
# 765391
# 691413
# 765545
# 693679
# 693672
# 766020
# 766139
# 766142
# 766148
# 766256
# 408940
# 766662
# 766714
# 766993
# 767023
# 767788
# 139539
# 768261
# 768340
# 699486
# 699035
# 698990
# 605733
# 768540
# 769286
# 606598
# 770817
# 770855
# 771733
# 771881
# 707221
# 264434
# 772714
# 772950
# 772975
# 602403
# 691990
# 774819
# 959749
# 775129
# 775316
# 775445
# 560977
# 776850
# 778321
# 778349
# 779509
# 780429
# 780969
# 781170
# 781256
# 244231
# 782319
# 782520
# 782626
# 782741
# 783006
# 659723
# 784167
# 482844
# 785736
# 786600
# 786752
# 649316
# 451647
# 597207
# 788443
# 788814
# 790043
# 790240
# 790534
# 791892
# 792323
# 792593
# 792733
# 793499
# 794271
# 569013
# 278185
# 798203
# 798806
# 798813
# 1024002
# 1083556
# 598919
# 800640
# 159351
# 376377
# 802510
# 802514
# 802710
# 679156
# 591666
# 803572
# 803601
# 1088032
# 636127
# 307342
# 449465
# 1026594
# 805123
# 805505
# 1028741
# 806891
# 806932
# 1159721
# 807519
# 807550
# 808277
# 446190
# 655023
# 809159
# 809677
# 809679
# 810315
# 810442
# 811344
# 811461
# 908252
# 643216
# 814632
# 815012
# 815047
# 815170
# 815175
# 815823
# 590966
# 358042
# 817788
# 903181
# 818397
# 818427
# 818519
# 1017014
# 818868
# 374139
# 876203
# 821983
# 822482
# 675340
# 823446
# 34330
# 675730
# 824154
# 824789
# 825445
# 825621
# 671559
# 525764
# 671001
# 670524
# 827572
# 576081
# 828329
# 828858
# 829428
# 668605
# 830778
# 831028
# 831135
# 831171
# 831681
# 832189
# 832814
# 566242
# 566252
# 1058037
# 175617
# 566136
# 566148
# 566174
# 566155
# 661734
# 565402
# 1058094
# 566378
# 566385
# 366868
# 566371
# 662291
# 302047
# 836648
# 565827
# 511867
# 662000
# 661916
# 837026
# 661588
# 301875
# 565493
# 837072
# 370408
# 661785
# 661743
# 661760
# 837100
# 661744
# 565821
# 839822
# 840486
# 840672
# 256126
# 979443
# 97634
# 495308
# 842266
# 755469
# 389664
# 844512
# 845043
# 740307
# 740259
# 846255
# 847941
# 849300
# 971977
# 759023
# 759027
# 759044
# 757385
# 851010
# 851275
# 522304
# 267442
# 394579
# 394504
# 851635
# 851994
# 525013
# 853134
# 853486
# 853560
# 853997
# 854146
# 678672
# 854435
# 855291
# 855400
# 855402
# 855926
# 599607
# 856177
# 856264
# 856576
# 801635
# 985704
# 796159
# 857781
# 858079
# 858139
# 384709
# 594630
# 858743
# 145606
# 860241
# 860581
# 860890
# 861215
# 861615
# 862575
# 681418
# 862938
# 863291
# 348158
# 457929
# 864055
# 864347
# 865036
# 865555
# 866879
# 866937
# 867080
# 867510
# 868896
# 869854
# 869958
# 870143
# 870177
# 871274
# 871354
# 871826
# 871857
# 871865
# 871867
# 872647
# 872959
# 873048
# 873894
# 873674
# 874595
# 874775
# 874823
# 875158
# 875182
# 826674
# 875581
# 877495
# 877772
# 878209
# 511085
# 829561
# 151269
# 879156
# 880148
# 662341
# 884429
# 301760
# 884718
# 836751
# 370895
# 836766
# 837172
# 837132
# 837133
# 553667
# 888826
# 890345
# 190214
# 891529
# 892730
# 892846
# 893459
# 746068
# 104526
# 894707
# 896531
# 896533
# 896535
# 896537
# 897140
# 750832
# 897280
# 898548
# 899351
# 899397
# 225663
# 747003
# 746984
# 899916
# 900043
# 902354
# 820109
# 903125
# 903383
# 903567
# 633118
# 904013
# 905839
# 4792
# 906554
# 907546
# 908608
# 533111
# 909443
# 654550
# 910834
# 910989
# 767701
# 912096
# 912298
# 767455
# 912617
# 223185
# 1026990
# 804639
# 1155691
# 804590
# 21416
# 913822
# 21361
# 538240
# 541377
# 450400
# 656623
# 915501
# 805113
# 917729
# 502717
# 919386
# 412625
# 919883
# 920569
# 1101274
# 132611
# 78246
# 924013
# 737813
# 924911
# 925161
# 763902
# 927123
# 927674
# 927848
# 768089
# 928928
# 929109
# 929344
# 931494
# 932634
# 696346
# 465156
# 933815
# 933970
# 934068
# 935073
# 198077
# 935697
# 936204
# 936229
# 936557
# 936587
# 936656
# 203160
# 652295
# 203024
# 937830
# 894290
# 899618
# 939848
# 940063
# 940136
# 940161
# 431690
# 1108217
# 940291
# 940303
# 845840
# 845549
# 940553
# 729346
# 940930
# 941711
# 941832
# 1110592
# 942131
# 429297
# 468878
# 943737
# 846141
# 1108029
# 1067615
# 945351
# 945373
# 945437
# 945811
# 163872
# 946415
# 946738
# 237814
# 947264
# 947625
# 671431
# 948196
# 948287
# 1186995
# 950759
# 950789
# 953061
# 247701
# 954764
# 931764
# 1201909
# 957926
# 959133
# 959296
# 75255
# 254468
# 131069
# 960317
# 254300
# 254366
# 960486
# 490440
# 1097111
# 626739
# 961505
# 765128
# 408339
# 962849
# 963375
# 963775
# 424908
# 964101
# 964553
# 964851
# 890304
# 965791
# 965840
# 214577
# 966160
# 966538
# 967153
# 967325
# 967663
# 534552
# 969293
# 730974
# 969951
# 970156
# 971905
# 1258412
# 972026
# 972139
# 972157
# 972281
# 972242
# 972402
# 972435
# 972433
# 727401
# 972572
# 972576
# 972610
# 972662
# 972689
# 853080
# 972803
# 972835
# 972888
# 973157
# 973178
# 617850
# 973706
# 851353
# 974326
# 974677
# 696798
# 975352
# 975453
# 976227
# 977282
# 976971
# 978170
# 981864
# 982046
# 682134
# 451441
# 322081
# 855371
# 984759
# 1057881
# 987038
# 988412
# 988411
# 990036
# 991014
# 681368
# 992440
# 994427
# 994559
# 994968
# 921487
# 995306
# 995572
# 609232
# 924248
# 998034
# 998120
# 998692
# 998818
# 999051
# 689061
# 690615
# 920628
# 799125
# 919040
# 603366
# 506138
# 1004955
# 884830
# 884851
# 836633
# 884751
# 884746
# 884745
# 884762
# 884666
# 884808
# 884390
# 1005712
# 1005714
# 1005716
# 1005721
# 884392
# 1005746
# 1005831
# 1005832
# 1005833
# 1005846
# 884703
# 884866
# 511979
# 1006631
# 884566
# 1006733
# 884547
# 884496
# 884596
# 884516
# 1007923
# 1008021
# 1008023
# 877560
# 580936
# 1010065
# 371366
# 1070383
# 1011344
# 869723
# 1011581
# 1011765
# 172941
# 1012811
# 168749
# 1012994
# 1012992
# 1013046
# 1014010
# 1014614
# 1015359
# 881668
# 1016031
# 325296
# 1018271
# 817202
# 1018795
# 1018793
# 325319
# 907984
# 1021101
# 908555
# 1021612
# 1021752
# 1021822
# 1021852
# 1022272
# 1023245
# 1023627
# 881141
# 1023817
# 281547
# 1024563
# 1024582
# 1024691
# 807312
# 1025335
# 442153
# 1029585
# 1026036
# 1028254
# 307265
# 1029537
# 1029666
# 818179
# 1030918
# 903255
# 1030420
# 903193
# 1031226
# 1031688
# 1031662
# 1031724
# 1031955
# 1032230
# 1033184
# 968105
# 1034231
# 1034961
# 1035624
# 1035648
# 589968
# 1036173
# 1036480
# 989181
# 444111
# 1041044
# 1042121
# 953860
# 1043083
# 1043207
# 1043395
# 1044103
# 1044991
# 1045102
# 1045636
# 1046032
# 548214
# 1047557
# 745418
# 1048546
# 1049115
# 1049278
# 1049363
# 938605
# 1236883
# 438757
# 936706
# 964626
# 1050789
# 1051873
# 1051956
# 1052399
# 1052778
# 1053397
# 1054196
# 1054460
# 185673
# 1056054
# 1056593
# 884525
# 1006734
# 1006737
# 1005637
# 1005800
# 1005806
# 1005817
# 1058612
# 1005718
# 1058680
# 1058691
# 1163269
# 1005834
# 1058699
# 1163249
# 1005838
# 1058706
# 1005844
# 1058732
# 1006326
# 1060013
# 1060289
# 1061777
# 1065529
# 523182
# 1066978
# 1067334
# 525773
# 575170
# 1067609
# 826340
# 1068384
# 1069491
# 1070403
# 822863
# 1071230
# 1071922
# 1072793
# 1074507
# 1074709
# 1075024
# 1075115
# 1075117
# 981400
# 352362
# 1076242
# 1076546
# 1078506
# 1079715
# 1080896
# 1081044
# 1002954
# 1002953
# 998731
# 1082587
# 1082885
# 1082997
# 1083573
# 798991
# 1084716
# 1085150
# 1085239
# 1085552
# 1086039
# 291541
# 859799
# 1087242
# 1087246
# 1087248
# 1087250
# 1000225
# 1087991
# 931481
# 931812
# 1089273
# 489675
# 1090396
# 693438
# 1090460
# 1090671
# 695883
# 1091428
# 1092224
# 959492
# 959195
# 1092618
# 1093532
# 1093717
# 1093720
# 1096183
# 1096495
# 1098186
# 1098713
# 1098722
# 614279
# 1099182
# 992552
# 1099356
# 701875
# 995307
# 1100091
# 335195
# 611499
# 995695
# 1102007
# 1102323
# 1102344
# 603003
# 1102669
# 771585
# 1003529
# 1103962
# 1104219
# 1104424
# 501435
# 1104930
# 338321
# 1105096
# 771276
# 401945
# 1105438
# 1001115
# 1105581
# 1106198
# 917454
# 1106511
# 1108727
# 1109143
# 1109538
# 720693
# 1110965
# 1111619
# 1258911
# 1111796
# 1112145
# 895920
# 748610
# 1114610
# 1114640
# 1114858
# 1115059
# 1117963
# 1118077
# 842215
# 1118347
# 1118563
# 1119072
# 1119577
# 1119592
# 851210
# 1119965
# 1120247
# 1120257
# 1120400
# 1120677
# 759144
# 972341
# 1121220
# 1122015
# 121106
# 969759
# 1126435
# 1128588
# 1037208
# 23555
# 1129542
# 1130260
# 1131393
# 451916
# 1133861
# 1134696
# 1135102
# 1136605
# 1136710
# 1136731
# 1138933
# 1139194
# 1140489
# 1142147
# 1142175
# 1142188
# 541898
# 1142898
# 1143478
# 1144607
# 1145603
# 19125
# 541559
# 1051223
# 1148266
# 1149037
# 1149457
# 1149488
# 1149490
# 909596
# 1153360
# 1153365
# 1153573
# 1154627
# 1155073
# 1156464
# 1026453
# 1158142
# 1158624
# 1159193
# 1159282
# 1161304
# 1161894
# 1005578
# 1058733
# 836453
# 1058683
# 1058661
# 1058657
# 1058702
# 1058700
# 884488
# 1058646
# 1163776
# 1164671
# 869773
# 1164909
# 1165435
# 1165583
# 1166236
# 1166267
# 1166405
# 1070700
# 1167343
# 1167696
# 1167863
# 581495
# 873009
# 1069762
# 1168713
# 151162
# 1169916
# 1170242
# 1170363
# 1170446
# 1171587
# 1171741
# 1171784
# 1172109
# 1172322
# 1172751
# 1172786
# 1173091
# 1173164
# 1173328
# 1174132
# 1174434
# 1174638
# 302163
# 370059
# 1174783
# 565602
# 176314
# 302304
# 1006624
# 837139
# 1006595
# 1175816
# 1176470
# 1176875
# 1176888
# 1177039
# 1177278
# 1009125
# 1178044
# 1178197
# 1178322
# 1086626
# 1178629
# 1178893
# 1178904
# 1178973
# 1179113
# 1179276
# 1087370
# 1087691
# 1179522
# 1179938
# 1180564
# 985489
# 1183038
# 1183936
# 856512
# 1184271
# 1184598
# 1085134
# 983736
# 1185535
# 1185630
# 1186420
# 1186944
# 1187045
# 1187344
# 1188131
# 1188458
# 1188631
# 1188857
# 1189103
# 1189118
# 1189412
# 1192740
# 1192940
# 1194371
# 1194647
# 1194808
# 1195039
# 1195131
# 1195355
# 1195617
# 1196167
# 1196130
# 1198072
# 756721
# 1198662
# 1198695
# 842141
# 974597
# 962462
# 1200926
# 1201921
# 1088702
# 1203124
# 1203313
# 1204338
# 961074
# 1205644
# 1205805
# 838183
# 1116468
# 1206706
# 616709
# 1207566
# 1207807
# 1207981
# 1208625
# 1208651
# 1208997
# 1209445
# 1209516
# 1209564
# 1209707
# 1209769
# 1210321
# 1210796
# 1210956
# 752774
# 1211193
# 1211196
# 1213028
# 1213031
# 1213937
# 1213956
# 1214092
# 1214328
# 1214533
# 1215802
# 1215026
# 1215115
# 1215201
# 1215204
# 1215930
# 735052
# 1216493
# 1216565
# 1216804
# 1216862
# 1217209
# 1217290
# 1218550
# 1218841
# 1219382
# 1101303
# 1219742
# 1219790
# 1220009
# 1220294
# 1222085
# 1223621
# 1224035
# 1224588
# 1224983
# 1227774
# 1228258
# 1229132
# 1229230
# 1229591
# 1230182
# 708764
# 1231090
# 1231313
# 1049043
# 1043988
# 1233290
# 559324
# 953021
# 951238
# 561740
# 1235518
# 1235539
# 1235797
# 1235870
# 562631
# 1236040
# 1236311
# 1237260
# 1049687
# 1237575
# 1238072
# 937925
# 1238278
# 1238858
# 1238862
# 1050136
# 1239760
# 1241624
# 1242081
# 1243249
# 1243336
# 1244134
# 891272
# 947489
# 1244729
# 1245025
# 1245079
# 1045325
# 1245744
# 1245863
# 183758
# 1046202
# 1246458
# 1250768
# 1251933
# 1252324
# 1252428
# 1253192
# 1254383
# 1254829
# 758024
# 1255328
# 1255793
# 1255963
# 1256493
# 1256598
# 1256999
# 1257415
# 1257668
# 1257681
# 1258456
# 1258502
# 1258598
# 934856
# 1259038
# 235758
# 1259347
# 235845
# 1259675
# 1260135
# 1261191
# 1261394
# 1107930
# 1107989
# 1264571
# 1265205
# 1266492
# 1267764
# 1267799
# 1203932
# 1268817
# 1268969
# 1424859
# 1202812
# 1269866
# 1270082
# 1203573
# 1270454
# 1270605
# 129306
# 1272447
# 1273159
# 1273385
# 1273684
# 1419729
# 1755907
# 1274106
# 1274179
# 1211071
# 1274257
# 1274293
# 1274350
# 1275314
# 1824815
# 1275453
# 1196637
# 1276884
# 1277487
# 1901697
# 1198867
# 2085964
# 1200250
# 1278082
# 1200181
# 1278279
# 1198687
# 1668844
# 1278445
# 2015347
# 1758504
# 1454091
# 1214172
# 1216050
# 1280666
# 1218217
# 1217831
# 1280861
# 1281422
# 1220146
# 1281582
# 1476352
# 1282008
# 1282040
# 1282639
# 1282714
# 2015473
# 1283178
# 1283232
# 1283643
# 1284093
# 1284086
# 2140250
# 1451309
# 1287469
# 1287522
# 1287923
# 1684390
# 1474720
# 1814311
# 1814252
# 1614518
# 1639836
# 1291596
# 1291620
# 2121229
# 2031970
# 1292248
# 1392613
# 1292459
# 1293426
# 1293661
# 1148367
# 1294224
# 1294423
# 1444383
# 1296080
# 1444318
# 1879542
# 1296860
# 1994446
# 1298001
# 1298010
# 1691880
# 1300295
# 1145189
# 1300622
# 1617021
# 1158955
# 1302638
# 587909
# 1512221
# 2254266
# 1303675
# 1303904
# 2163743
# 1149189
# 968221
# 1143412
# 1143438
# 1305413
# 963990
# 1306189
# 1145762
# 1307121
# 1307361
# 1307638
# 1307649
# 1307915
# 1308606
# 1308832
# 1309192
# 1309395
# 1258138
# 1974740
# 1430531
# 1310234
# 1310304
# 1310443
# 1310638
# 1254427
# 1438026
# 1310821
# 1311012
# 1822086
# 1255105
# 1121802
# 972063
# 1253625
# 1705529
# 1312399
# 1820564
# 1820966
# 1313975
# 1207058
# 1316336
# 1316440
# 1437086
# 1437479
# 1317119
# 1317299
# 1604940
# 1435817
# 1317738
# 1207182
# 1447426
# 1237415
# 1447070
# 1446835
# 1446755
# 1320305
# 1320396
# 1532805
# 1688950
# 1320933
# 1321401
# 1887188
# 1321605
# 1321738
# 1321800
# 937668
# 1768712
# 1322545
# 2091262
# 901126
# 1239793
# 1323558
# 1323582
# 1324149
# 1325183
# 1325698
# 1325454
# 1603432
# 1326365
# 1438308
# 1869940
# 1797627
# 1327605
# 1328399
# 1328556
# 148222
# 1328908
# 1329437
# 1329633
# 1330364
# 1330522
# 1397465
# 1330712
# 2013906
# 1582532
# 884467
# 1330875
# 1330878
# 1330880
# 1582525
# 1582524
# 1829873
# 2012121
# 1331161
# 1175124
# 1162619
# 1331591
# 1651217
# 1651216
# 1162590
# 1651222
# 1058620
# 1331676
# 1163216
# 1547228
# 1331848
# 2014623
# 1332677
# 1332688
# 1193261
# 1192007
# 1193539
# 1333772
# 1192543
# 1333907
# 1334698
# 1170903
# 1336442
# 1589776
# 2270261
# 1337681
# 1173193
# 797869
# 1338738
# 1338864
# 1338995
# 1187047
# 1339190
# 1339295
# 1339730
# 1340265
# 1340562
# 1340943
# 1341142
# 1341200
# 1736742
# 1195686
# 1188854
# 1651969
# 946295
# 1342365
# 1584068
# 1346380
# 1342924
# 1726830
# 1549193
# 1070752
# 1580443
# 1343661
# 1726895
# 1549246
# 1548615
# 1161166
# 1345474
# 1166336
# 1655502
# 1345722
# 1346106
# 1346127
# 1346259
# 1346353
# 1346523
# 1166891
# 2009124
# 1346931
# 1346933
# 1346940
# 1346942
# 1346944
# 1543470
# 1347274
# 1403350
# 2054324
# 1377335
# 1579073
# 1348996
# 1349182
# 1951679
# 1138902
# 1353526
# 2042554
# 1353703
# 1354252
# 1354393
# 1579637
# 1578271
# 1573024
# 1130922
# 1710236
# 1130149
# 1357080
# 1357338
# 1357364
# 1357643
# 1357658
# 1357853
# 1357976
# 1358159
# 1358173
# 380959
# 1657665
# 285820
# 1360180
# 1360209
# 1498363
# 1360253
# 690289
# 380387
# 1361658
# 1361663
# 1362344
# 1500638
# 1363239
# 1137915
# 1364004
# 1364584
# 1365875
# 1365900
# 1365974
# 1366005
# 1917179
# 1366678
# 1353637
# 1367199
# 1367632
# 1368708
# 1370108
# 1353183
# 1370567
# 1935821
# 1303786
# 1372378
# 1372630
# 1372696
# 2030863
# 1373416
# 1373918
# 1373920
# 1375705
# 1348871
# 1348721
# 1132073
# 1349930
# 1349641
# 1379836
# 1380379
# 1380639
# 1381289
# 1249234
# 1382123
# 1624657
# 2121565
# 1383044
# 1240756
# 1383401
# 1294627
# 1384377
# 1296729
# 1384772
# 1883020
# 1385568
# 1234609
# 1044726
# 1386904
# 1387482
# 1387516
# 1149378
# 1387915
# 2115527
# 1389230
# 1389792
# 1389732
# 1389887
# 1798438
# 537443
# 1390625
# 1391537
# 1391481
# 911401
# 1391616
# 1391687
# 1391789
# 1392196
# 1392881
# 1147385
# 1006730
# 1005672
# 1394732
# 1342985
# 1395205
# 1395460
# 1343394
# 2155119
# 1396095
# 2155564
# 1549447
# 1396426
# 1328600
# 1396808
# 1397132
# 1397640
# 1397988
# 1399072
# 1332205
# 1332204
# 1399886
# 1399897
# 1400185
# 1188155
# 1400284
# 1341733
# 1400439
# 1400495
# 1656166
# 1190725
# 1401359
# 1401454
# 1402079
# 1402393
# 1193773
# 1067801
# 1193841
# 1167747
# 1404247
# 1404266
# 1404268
# 1580854
# 1167061
# 1404385
# 1339567
# 1405214
# 1405265
# 1405271
# 1405652
# 1405669
# 1544941
# 1406185
# 1406282
# 1184351
# 1497537
# 1660677
# 1359059
# 1186300
# 1657457
# 1409244
# 1409294
# 1409593
# 1409600
# 1362334
# 1362472
# 1411297
# 1336899
# 1334030
# 1666593
# 1414251
# 1333806
# 2066427
# 2003719
# 1665561
# 1415162
# 1415190
# 1415608
# 1535400
# 1335633
# 1335530
# 1088026
# 1417525
# 1334940
# 1418505
# 1539446
# 1418890
# 1418998
# 1419502
# 1275340
# 1420633
# 1420826
# 1421436
# 1421711
# 2129304
# 1422427
# 1315748
# 1905771
# 1670525
# 1425289
# 1669167
# 1426598
# 1276053
# 1427814
# 1428021
# 1428303
# 1747554
# 1277135
# 1747119
# 1428724
# 1428779
# 1313464
# 1429573
# 1429886
# 1311935
# 1430064
# 1430092
# 1430246
# 1876227
# 1430560
# 1431402
# 1431621
# 1431903
# 1431995
# 1432031
# 1432210
# 1468278
# 1433348
# 1705894
# 1433364
# 1324729
# 1433654
# 266659
# 1434475
# 1434745
# 1435473
# 1209015
# 1435577
# 1435830
# 1435928
# 1310827
# 1309327
# 1471517
# 1778660
# 1308968
# 1309033
# 1436508
# 1436596
# 1436647
# 1436675
# 1471965
# 1309423
# 1316839
# 1877638
# 1877845
# 1254290
# 1310366
# 1699891
# 1327341
# 1439238
# 1439434
# 1703404
# 1326164
# 1326362
# 1440435
# 2221972
# 1440694
# 1440720
# 1440725
# 1440730
# 1440755
# 1281706
# 1442558
# 2090831
# 1532133
# 1443085
# 1233986
# 1444452
# 1321550
# 1321549
# 1445282
# 1320812
# 1445612
# 1445619
# 1600797
# 1446391
# 1447558
# 1447588
# 1284161
# 1449043
# 1448605
# 1449331
# 1767234
# 1684371
# 1449778
# 1449997
# 1450047
# 1450953
# 1451256
# 1558406
# 1452696
# 1453192
# 1453377
# 1454288
# 1478266
# 1455052
# 1455567
# 1839736
# 1455895
# 1455949
# 1455951
# 1281030
# 1287869
# 1287707
# 1287749
# 1456692
# 1287752
# 1435312
# 1827281
# 1459844
# 1434766
# 1460959
# 1902059
# 1199982
# 1462956
# 1463735
# 1464277
# 1464298
# 1464897
# 1428884
# 1466356
# 1433034
# 549347
# 1468548
# 1468604
# 1468613
# 1778393
# 1974460
# 1470502
# 1256781
# 1875661
# 1471694
# 1437710
# 1975514
# 1473461
# 1473589
# 1455226
# 1474871
# 1476012
# 1560010
# 1476388
# 1476563
# 1442548
# 1476687
# 1477553
# 2114871
# 1477751
# 1478461
# 1478741
# 1478905
# 1479193
# 1559943
# 405474
# 1480287
# 1203980
# 1481038
# 1481719
# 1268966
# 1428498
# 1808635
# 1483925
# 2273841
# 1090500
# 1484628
# 2139391
# 1485176
# 1485694
# 1764343
# 1765124
# 1489801
# 1489966
# 1490556
# 1490552
# 1350211
# 1373921
# 1491386
# 1492139
# 1356384
# 1493588
# 1495227
# 1495684
# 2061187
# 1496098
# 1496330
# 1496718
# 1738867
# 1416599
# 1498120
# 1498236
# 1498242
# 1417527
# 2057626
# 1359799
# 1499056
# 1500755
# 1363993
# 1501595
# 1915980
# 1993203
# 1504831
# 1505568
# 1505585
# 1505770
# 1142686
# 1506348
# 1506962
# 1507231
# 1297549
# 1937680
# 2120199
# 1391024
# 1510543
# 1510494
# 1510804
# 2120522
# 2243897
# 1368125
# 1300082
# 1303211
# 1512557
# 1514654
# 1516772
# 1517388
# 1300600
# 1617285
# 1963232
# 1518863
# 1518992
# 1386431
# 1520780
# 1520829
# 2087159
# 1520874
# 1521090
# 1444618
# 1521347
# 898115
# 1402873
# 1523303
# 1523633
# 1523720
# 1524146
# 1524440
# 1385204
# 1326893
# 1326151
# 1440419
# 1527844
# 1440027
# 1530802
# 1771963
# 1530939
# 1531433
# 1531865
# 1531915
# 1532402
# 1533013
# 1533173
# 1533253
# 1533793
# 1690929
# 1397545
# 1534563
# 1063326
# 1535731
# 1414708
# 1537234
# 1537865
# 1537876
# 1538078
# 1538420
# 1418481
# 1416735
# 1665405
# 1417029
# 1540211
# 1540511
# 1540605
# 1540983
# 1171886
# 1541733
# 1403754
# 1542254
# 1542506
# 2157878
# 1543111
# 1403187
# 1930087
# 1543405
# 1543417
# 1543431
# 1543874
# 1587236
# 1545394
# 1545434
# 1926979
# 565404
# 1394058
# 1731118
# 1394452
# 1394053
# 1650988
# 1549051
# 1669939
# 1549837
# 1550103
# 1480482
# 1426138
# 1550995
# 1551465
# 1551423
# 1553820
# 1554036
# 1420965
# 1554352
# 1554493
# 1670492
# 1276734
# 1482619
# 1557006
# 1557822
# 994802
# 1560597
# 1560827
# 1561090
# 1280065
# 1562359
# 1562444
# 1562759
# 1563229
# 1563445
# 1476129
# 1564159
# 1501389
# 1565291
# 1566199
# 2037569
# 1568037
# 1568773
# 1570156
# 1497076
# 1183918
# 1573556
# 1573802
# 1949527
# 1575760
# 1577278
# 1374852
# 1578387
# 1377317
# 1579283
# 1579285
# 1580216
# 1581429
# 1581561
# 1394791
# 1546110
# 1583815
# 1583790
# 1583820
# 1583920
# 1584102
# 1584193
# 1341912
# 1584569
# 1585073
# 1585075
# 1067846
# 1585172
# 1585199
# 1585378
# 2053542
# 1523084
# 1585618
# 1585622
# 1585653
# 1585769
# 1586036
# 1586227
# 1586246
# 1545112
# 1586323
# 1586736
# 1587045
# 1587596
# 1588190
# 1588521
# 1538746
# 1540213
# 1337188
# 1590310
# 1590602
# 1539625
# 1334850
# 1590975
# 1335379
# 1334473
# 1335329
# 1360608
# 1591716
# 1592432
# 1592656
# 1394262
# 1394261
# 1332689
# 1594200
# 1661757
# 1594377
# 1663494
# 1744191
# 1324730
# 1596039
# 1867997
# 1432436
# 1795368
# 2106067
# 1697789
# 1598102
# 1598314
# 1598321
# 1465071
# 1599794
# 1599831
# 1320862
# 1599902
# 1527550
# 1602074
# 1602227
# 1603469
# 1603507
# 1603588
# 1603725
# 1606495
# 1607923
# 1254485
# 1310269
# 1257267
# 1608616
# 1608659
# 1608766
# 1609286
# 1436656
# 1609394
# 1609694
# 1874121
# 1469511
# 1469552
# 1610029
# 1610283
# 1610991
# 1611182
# 1611899
# 1292884
# 1390405
# 1612077
# 531550
# 2120495
# 1614850
# 1509943
# 1615329
# 1615379
# 1518252
# 1307088
# 1616162
# 1617598
# 1305107
# 1386782
# 1617822
# 1505504
# 1618012
# 1618474
# 1389519
# 1801717
# 1620382
# 1530893
# 2247807
# 1688311
# 1688273
# 1622561
# 1622648
# 1321106
# 1622975
# 1624159
# 1624644
# 1291526
# 1624904
# 1524760
# 1386288
# 2041553
# 1628226
# 1379640
# 1629784
# 1493404
# 1573288
# 1567455
# 1633173
# 1635796
# 1636860
# 1637198
# 1637300
# 1637945
# 1638055
# 1613182
# 1638138
# 1638249
# 1638942
# 1941092
# 1639557
# 1639935
# 1509271
# 1640561
# 1641044
# 1993248
# 2122036
# 1641969
# 1575195
# 1644054
# 1616408
# 1645277
# 1645329
# 1647060
# 1647396
# 1647517
# 1647559
# 1648459
# 1830494
# 1649266
# 1829728
# 1651982
# 1342455
# 1653320
# 1653489
# 1956975
# 1728423
# 1655297
# 1735195
# 1733119
# 1189805
# 1656965
# 2005974
# 1589812
# 1658200
# 1658431
# 1499325
# 1659071
# 1568675
# 1660688
# 1571747
# 1571034
# 1661930
# 2005163
# 1663312
# 1664338
# 1664458
# 1665883
# 2003391
# 1666605
# 1667006
# 1667676
# 1668341
# 1668945
# 1669051
# 1550810
# 1669287
# 1670730
# 1673637
# 1609678
# 1674026
# 1674239
# 1675718
# 1676861
# 1677294
# 1677397
# 1677468
# 1678249
# 1279978
# 1895722
# 1679127
# 1220246
# 1681399
# 1684515
# 1685036
# 1686042
# 1686163
# 1686577
# 1687780
# 1687855
# 1687876
# 1688712
# 1689505
# 1690572
# 1690891
# 1600981
# 1692080
# 885578
# 1692542
# 1692535
# 1692537
# 1692539
# 1692782
# 1693168
# 1248039
# 2088745
# 1620758
# 1522529
# 2113266
# 1231785
# 1964656
# 1608610
# 1696881
# 1609248
# 1868762
# 1697929
# 1698345
# 1698843
# 1872962
# 1699882
# 1700289
# 1700710
# 470800
# 1701663
# 2203449
# 1702700
# 1702756
# 1702840
# 429651
# 1311518
# 1704531
# 1433360
# 1705947
# 1705952
# 1355653
# 1579450
# 1629660
# 1706783
# 1707076
# 1707943
# 1948439
# 1849837
# 1855420
# 2160309
# 1364172
# 1634196
# 1633210
# 1564731
# 1712826
# 1986417
# 1713241
# 1714174
# 1636022
# 1566050
# 1716299
# 1716421
# 2116308
# 1716476
# 1716673
# 1716760
# 1801737
# 1717832
# 1717936
# 1308405
# 1718320
# 1999807
# 1390823
# 1719263
# 1720118
# 1720307
# 1390719
# 1390123
# 1999221
# 1642700
# 1722596
# 1646567
# 1515492
# 1724426
# 1725637
# 1649440
# 1727532
# 1727607
# 1648820
# 1930073
# 1728360
# 1543260
# 1730023
# 1829636
# 1651740
# 1394676
# 1732206
# 1732258
# 1733142
# 1734036
# 1734651
# 869677
# 1653333
# 1657280
# 1179330
# 2147854
# 1738561
# 1861935
# 1739403
# 1739920
# 1740124
# 1740316
# 1740460
# 1741548
# 1358715
# 1742089
# 1743442
# 1743544
# 1744471
# 1666246
# 1744806
# 1745290
# 1745469
# 1745760
# 1745923
# 1746333
# 1414413
# 1746975
# 1482552
# 1811986
# 2019149
# 1747858
# 1196968
# 1553681
# 1276246
# 1751149
# 1751279
# 1751466
# 1751677
# 1752087
# 1424480
# 1752686
# 1753621
# 1207283
# 1754757
# 1606439
# 1973964
# 1973106
# 1755570
# 1755686
# 1198887
# 1420778
# 1462696
# 1757717
# 1213852
# 1758527
# 1759480
# 1760822
# 1761666
# 2210765
# 1762154
# 1762156
# 1762191
# 1551570
# 1762727
# 1892985
# 1763456
# 1552453
# 1685832
# 2024156
# 1766912
# 1767574
# 1532174
# 1768119
# 1443019
# 1768311
# 1687090
# 1321657
# 1769364
# 1444497
# 1769606
# 1263015
# 1770978
# 1957492
# 1771148
# 1236702
# 1772710
# 1772844
# 1772937
# 1773856
# 1776205
# 1776650
# 1777332
# 1777596
# 1777822
# 1778150
# 1472031
# 1778476
# 1471469
# 1778710
# 1607750
# 1779127
# 1471587
# 1697871
# 1875875
# 1780067
# 1699473
# 1780802
# 1780859
# 1781584
# 1781693
# 1782128
# 1821967
# 1782621
# 1979189
# 1783075
# 2101406
# 1784921
# 1786534
# 1598935
# 1705332
# 1789139
# 1789768
# 1771482
# 1601324
# 1689949
# 1790858
# 1687574
# 1791500
# 1769220
# 1687659
# 1792156
# 1792577
# 1792617
# 1443285
# 1792907
# 2241086
# 1793113
# 1793198
# 1793196
# 1793308
# 1960389
# 1703841
# 1324693
# 1793872
# 1975758
# 1795730
# 1795758
# 1702860
# 1795821
# 1795966
# 1796993
# 1701143
# 1797765
# 1798205
# 1503689
# 1720255
# 1692859
# 1720051
# 1718357
# 1800957
# 1801642
# 1934561
# 1801543
# 1718476
# 1801718
# 1717744
# 2118872
# 2035284
# 1618359
# 1695513
# 1803347
# 1777601
# 1695635
# 1519186
# 1295779
# 1804858
# 1235189
# 1235186
# 1805429
# 1805454
# 1693532
# 1806242
# 1806317
# 1773638
# 2127170
# 1809014
# 1809197
# 1809956
# 2281761
# 1810614
# 1810647
# 1748979
# 1810752
# 1810990
# 1755528
# 1811726
# 1667578
# 1908871
# 1812598
# 1275883
# 1813194
# 1813587
# 1814475
# 1815186
# 1818317
# 2188302
# 1820305
# 1820856
# 1821729
# 1607951
# 1822242
# 1822396
# 1875819
# 1824166
# 1824332
# 1824816
# 1824943
# 1419571
# 1459081
# 1754046
# 1827017
# 1650977
# 1650991
# 1829625
# 1829628
# 1650981
# 1829691
# 1347511
# 1728291
# 872642
# 1830509
# 1830563
# 1727809
# 1830705
# 1831186
# 1831156
# 2282986
# 1831376
# 1342870
# 1833346
# 1833830
# 1834221
# 1538634
# 1834402
# 1834858
# 1745007
# 1835023
# 1834934
# 1663300
# 1835678
# 2011751
# 1742331
# 1837060
# 2004380
# 1837975
# 1454838
# 1839846
# 1760898
# 1840701
# 1840799
# 1760997
# 1842570
# 2055538
# 1842599
# 1523812
# 1339022
# 1544728
# 1844669
# 1955938
# 2287493
# 1524030
# 1846728
# 1735912
# 2152788
# 1847431
# 1847463
# 1356991
# 1848345
# 1850235
# 1348730
# 1851467
# 1379500
# 1852513
# 1644843
# 1853674
# 1717911
# 1367238
# 1722327
# 1856681
# 1085670
# 290488
# 158253
# 1858070
# 1186636
# 1739687
# 1571371
# 162284
# 1859914
# 1860329
# 1745678
# 1335245
# 2064117
# 1860451
# 1664609
# 1665249
# 1665214
# 1860939
# 1861996
# 1862739
# 1864554
# 1864800
# 1865123
# 1412803
# 1711259
# 1867342
# 1786841
# 1868169
# 1597731
# 1868812
# 1869111
# 1869654
# 1870586
# 1870669
# 1793989
# 1873089
# 1873250
# 1873477
# 1873485
# 1753881
# 1874781
# 1781378
# 1875062
# 1875238
# 2100500
# 1696691
# 1876002
# 1877304
# 1878728
# 1878945
# 1769577
# 1233502
# 2181753
# 1881313
# 1881505
# 2227848
# 1881998
# 1883199
# 1883739
# 1884229
# 1884476
# 1884794
# 1770580
# 1885592
# 1886302
# 1239246
# 1322006
# 1321619
# 1790993
# 1959314
# 1889796
# 1890383
# 1890410
# 1891091
# 1891102
# 1289121
# 1891168
# 1891343
# 1814498
# 1449039
# 1892901
# 1893537
# 1895371
# 1895554
# 1761044
# 1559047
# 1281931
# 1896844
# 1896947
# 1897041
# 1897532
# 1419623
# 1900676
# 1824781
# 1811542
# 1902822
# 1903383
# 1903440
# 839520
# 1815646
# 1907284
# 1199675
# 1909140
# 1482565
# 1910048
# 2066003
# 1745006
# 1910689
# 1834220
# 1541169
# 1911139
# 1912548
# 1912810
# 1913413
# 1913629
# 1913735
# 1837244
# 1914472
# 1914582
# 1743209
# 1833495
# 1916415
# 1917011
# 1917200
# 1659984
# 2045844
# 1917876
# 1918144
# 1918441
# 1365020
# 1918635
# 1918704
# 1918866
# 1919153
# 1738358
# 1861675
# 1359770
# 1857741
# 1921787
# 1922362
# 1830985
# 1581167
# 1542623
# 1922804
# 1922909
# 1923016
# 1734247
# 1924181
# 1924208
# 1924355
# 1924394
# 1925701
# 1187233
# 1926637
# 1398647
# 885154
# 1927140
# 1927141
# 885155
# 1731215
# 1731194
# 1650664
# 1928157
# 1928444
# 1928547
# 1399648
# 1929394
# 1929431
# 1012656
# 1930571
# 1931634
# 1931715
# 2262745
# 1932052
# 1932102
# 1936780
# 1936898
# 1937851
# 1939261
# 1939592
# 1290038
# 1941551
# 1942477
# 1942687
# 1503722
# 2172382
# 1944127
# 2319115
# 1944596
# 1945245
# 2044140
# 1946537
# 1946552
# 1947399
# 1947420
# 1375614
# 1948252
# 1948543
# 1354389
# 1709054
# 1849366
# 1950092
# 1950128
# 1950698
# 2159788
# 1850305
# 1494142
# 1376912
# 1847718
# 1706816
# 2159468
# 1954276
# 1954273
# 1954293
# 1954305
# 1955143
# 2288846
# 1955205
# 1340262
# 1956805
# 1957273
# 1886005
# 1957476
# 1957566
# 1957569
# 1957606
# 1790499
# 1957782
# 1957898
# 1957913
# 1958090
# 1958411
# 1958450
# 1884938
# 1622151
# 2184334
# 1960210
# 1960519
# 1694023
# 1878108
# 1963347
# 1775981
# 1298172
# 553790
# 1965064
# 1965249
# 1965251
# 1965741
# 1965975
# 1966419
# 1966581
# 1966610
# 1966902
# 1967008
# 1967079
# 1879583
# 1967470
# 1967629
# 434403
# 1887341
# 1969239
# 1823180
# 1970384
# 1902398
# 1903353
# 1605057
# 1748923
# 1971898
# 1748746
# 1973487
# 1973586
# 1461615
# 1667936
# 1973830
# 1974219
# 1974910
# 1974995
# 1875512
# 1609374
# 1975409
# 1975503
# 1869677
# 1975934
# 1311615
# 1976477
# 1977284
# 1977265
# 1977314
# 1977740
# 1978675
# 1818597
# 1978885
# 1979187
# 1979702
# 1629141
# 1980336
# 1980665
# 1980802
# 1981199
# 209614
# 1982036
# 1710594
# 1948783
# 1493234
# 1985305
# 1411548
# 1712923
# 1986547
# 1986902
# 1987359
# 1568288
# 1920020
# 1741439
# 2171498
# 1741689
# 1406749
# 2315592
# 1947168
# 1988374
# 1633471
# 1988836
# 1988934
# 1989454
# 1865041
# 1294390
# 1938423
# 1243866
# 2092626
# 1992534
# 1992730
# 1942088
# 1942728
# 1880650
# 1994886
# 1774080
# 1995098
# 1774135
# 1247555
# 1997275
# 2028837
# 2167320
# 1998708
# 1512242
# 1934926
# 1856936
# 1999641
# 1999647
# 2000595
# 2001875
# 2003202
# 2003220
# 2003353
# 2003942
# 2004244
# 2004506
# 2005458
# 2006944
# 2007439
# 2007741
# 2146275
# 2009433
# 2010165
# 1406292
# 2010930
# 2010978
# 2011961
# 2049575
# 2143994
# 2012804
# 2012874
# 2013022
# 509865
# 2013603
# 2013905
# 1829639
# 2013987
# 2144337
# 1926677
# 1479938
# 2015076
# 1838413
# 2015514
# 2015922
# 2016000
# 1839838
# 1897945
# 1678393
# 2016938
# 2016964
# 1839671
# 2018131
# 2083846
# 2018681
# 2019421
# 2019560
# 2020047
# 2020701
# 1895552
# 1480521
# 1810290
# 1683534
# 2023422
# 1560769
# 1845962
# 2024394
# 2024630
# 1563275
# 1476041
# 2025202
# 2025225
# 1685524
# 2025572
# 2026830
# 1983406
# 2029651
# 2029792
# 2029988
# 2030858
# 65708
# 1992664
# 2032993
# 1933636
# 2034426
# 2034386
# 2034414
# 1717785
# 2034567
# 2034672
# 2034868
# 2034953
# 1304469
# 2035607
# 2035968
# 1947310
# 2037647
# 2037747
# 2037813
# 2038010
# 2038475
# 2038484
# 2039038
# 2039040
# 2039042
# 2039045
# 2039055
# 2039060
# 2039064
# 2039067
# 2039069
# 2039219
# 2040129
# 2041992
# 1355863
# 1984485
# 2043011
# 1984910
# 2044496
# 2045049
# 1366410
# 2045863
# 2156515
# 1929426
# 2013934
# 2048489
# 2014068
# 2014170
# 2048519
# 2048690
# 1926933
# 1926948
# 2014002
# 2144320
# 1926656
# 2049025
# 2049310
# 1927129
# 1927033
# 2049622
# 2051254
# 2051308
# 1652099
# 1956585
# 2051601
# 2052115
# 2052267
# 2052437
# 2052989
# 1340842
# 1581169
# 2053846
# 2054573
# 2054800
# 2055703
# 2057437
# 2057781
# 2005531
# 2058917
# 2171463
# 1985730
# 1918001
# 2059798
# 2059854
# 1913101
# 2062237
# 1335784
# 2062999
# 2007645
# 2064055
# 1664330
# 2065943
# 2149877
# 2066448
# 2066466
# 2066467
# 2066981
# 2067793
# 2068399
# 2069247
# 2069313
# 2015131
# 2072878
# 2074315
# 2136078
# 2074848
# 2074877
# 1455280
# 2075996
# 2076729
# 1977436
# 1781023
# 2079599
# 2079791
# 2079924
# 2080089
# 2080179
# 2080202
# 2080990
# 2081087
# 2081135
# 1909892
# 2081752
# 2081890
# 2082623
# 1751580
# 1824517
# 1900618
# 2085112
# 1553450
# 1909004
# 2086046
# 2087927
# 2088028
# 2088117
# 2088702
# 2089024
# 2089066
# 1687083
# 2089180
# 2089802
# 2181814
# 2090705
# 1768220
# 1996467
# 2092171
# 1509040
# 1937840
# 2093072
# 2093863
# 2094352
# 2094508
# 2094576
# 2094747
# 1386001
# 2095324
# 2095916
# 2097243
# 1432741
# 2097889
# 2098041
# 2192190
# 1976213
# 2099355
# 1896664
# 1258346
# 2100287
# 2100595
# 2100851
# 1778664
# 2101766
# 2101736
# 2178591
# 2103166
# 2103241
# 2104300
# 2106403
# 2106426
# 2106529
# 2106827
# 2095040
# 2107789
# 2107919
# 2107926
# 2108089
# 2108322
# 2108512
# 2109510
# 2111173
# 2111332
# 2111470
# 2111903
# 2112016
# 1279818
# 1898597
# 2112258
# 2113957
# 2114515
# 2115336
# 2115545
# 2116184
# 2116846
# 2118468
# 2118639
# 2118753
# 2119652
# 1054779
# 2121011
# 2121085
# 2121474
# 2121564
# 2121981
# 1305727
# 2122372
# 2122962
# 2123811
# 2124079
# 1908116
# 2082108
# 2124727
# 2124853
# 2124913
# 2125591
# 1810666
# 2125945
# 2126585
# 2127315
# 2127354
# 2077400
# 2076974
# 2129664
# 2130643
# 2130627
# 2131083
# 2131177
# 2132277
# 2301794
# 769658
# 1890094
# 2024959
# 2133674
# 2133786
# 2133835
# 2134045
# 2135013
# 1839441
# 2135417
# 2135426
# 2135488
# 2135885
# 2139165
# 2139577
# 2139960
# 2140132
# 1893936
# 2140341
# 2141624
# 1836939
# 2142602
# 2142835
# 2143262
# 2145130
# 2144010
# 1836209
# 2144080
# 2144268
# 2264050
# 2145191
# 2145212
# 2145562
# 2145564
# 2145686
# 1328961
# 1537485
# 1592272
# 2146117
# 1911848
# 2268176
# 2147742
# 2147987
# 2148353
# 2148474
# 1333503
# 2149397
# 1925629
# 2289807
# 2289187
# 1844975
# 2153735
# 2154183
# 1342700
# 1926149
# 2155745
# 2156413
# 1586421
# 2157839
# 2157959
# 2159198
# 2159199
# 2159858
# 2160246
# 2161562
# 1125696
# 2163551
# 2163682
# 2166138
# 2042429
# 2167080
# 1570959
# 2168316
# 2168346
# 2058855
# 2060205
# 2314190
# 1406682
# 1636365
# 2173472
# 1577293
# 2175001
# 2175717
# 2175883
# 2178409
# 2178477
# 1599901
# 2178580
# 2180708
# 2181116
# 2091142
# 2181436
# 1968309
# 1687723
# 898167
# 2182529
# 2089537
# 1788777
# 2183525
# 2183626
# 2183643
# 2183674
# 2183759
# 2183886
# 2183896
# 1959275
# 2184805
# 2100049
# 2185031
# 1821541
# 2185141
# 2186054
# 1254993
# 2185725
# 2186870
# 2186880
# 2187044
# 2187365
# 2187600
# 2219471
# 2188532
# 2188538
# 2188690
# 2188701
# 2189323
# 2100809
# 1961340
# 2190546
# 2190812
# 1596562
# 2191497
# 1975654
# 2191664
# 2191949
# 2193894
# 2193896
# 1877518
# 2195339
# 2195341
# 2195332
# 2195468
# 2189219
# 2195638
# 2196081
# 2196551
# 1979829
# 2196918
# 2196941
# 2197279
# 2197319
# 2197985
# 2198138
# 1598340
# 1820812
# 2198950
# 2185080
# 1609077
# 2199664
# 2185162
# 2097076
# 2200195
# 2201220
# 2201363
# 2201958
# 2202170
# 2202361
# 2202721
# 2203059
# 2203096
# 2203192
# 2203571
# 2203644
# 2203884
# 2203980
# 2204157
# 2204466
# 2204603
# 2204907
# 2205171
# 2205467
# 2205470
# 2205907
# 1962318
# 2206954
# 2207679
# 2208256
# 2208480
# 2208607
# 2209074
# 2209312
# 2209401
# 2111844
# 2210168
# 2210475
# 2210648
# 1898144
# 2072230
# 2214038
# 2216209
# 2216377
# 2218574
# 2219375
# 2219876
# 2220236
# 2220390
# 2221554
# 2221873
# 2114747
# 2222670
# 2222851
# 2223221
# 2223375
# 2224528
# 2224515
# 2224593
# 2224695
# 2225110
# 2226949
# 2096040
# 1994559
# 2228853
# 2232196
# 2232735
# 2232915
# 2233944
# 2234313
# 2090153
# 560287
# 2237464
# 2237598
# 2237689
# 2238082
# 2109724
# 2238701
# 2238801
# 2238803
# 2239209
# 2240127
# 2240130
# 2240851
# 2091280
# 2241145
# 2182336
# 2241391
# 2241429
# 1688400
# 2241752
# 2242418
# 1856902
# 2244161
# 2244164
# 2244828
# 2245096
# 2245829
# 2246289
# 2246400
# 2246571
# 2248445
# 1718602
# 2249357
# 2250007
# 2250148
# 2250168
# 1516589
# 2250410
# 2250723
# 2251353
# 2251402
# 2252173
# 2255294
# 2255783
# 2256837
# 2256903
# 2257418
# 2257542
# 2258128
# 2259133
# 2259298
# 2142417
# 2259868
# 2062802
# 2013014
# 2260383
# 2260856
# 2260960
# 2262492
# 2262855
# 2263213
# 2263299
# 1582485
# 1926839
# 1582783
# 2263739
# 2263990
# 2265388
# 2265817
# 2266905
# 2267526
# 2267856
# 2269447
# 2269473
# 2269686
# 2269964
# 2270353
# 2270912
# 2271120
# 2271931
# 2273013
# 2149069
# 1662465
# 2273959
# 1671287
# 2274843
# 2274879
# 2274909
# 2274937
# 2082457
# 2276021
# 2277035
# 2277346
# 2277789
# 2277931
# 2278437
# 2278487
# 2278700
# 2279061
# 1824197
# 2279625
# 2280091
# 2280531
# 2280871
# 2281526
# 1461039
# 2282835
# 2011246
# 2283376
# 2283571
# 2055720
# 2010744
# 2284085
# 2285012
# 2285122
# 2285153
# 2285604
# 2285970
# 2286299
# 2153653
# 2287308
# 2287681
# 2287698
# 2287982
# 2288003
# 2288801
# 2288843
# 2288914
# 2288948
# 2289267
# 2289334
# 2289449
# 2290034
# 2290025
# 2290782
# 2292071
# 2292291
# 2294415
# 2295144
# 2296625
# 2297632
# 2297916
# 2297920
# 2299297
# 2299351
# 1223233
# 2299819
# 2300127
# 2026002
# 2301732
# 2302230
# 2302263
# 2302420
# 2134450
# 2303340
# 2307412
# 2307929
# 2308681
# 2310884
# 2310908
# 2311381
# 2311628
# 2312037
# 2170681
# 2313215
# 1858319
# 2171462
# 2315461
# 2318792
# 2319565
# 2320293
# 2037626
# 2320517
# 2320673
# 2175719
# 2320787
# 2321017
# 2321138
# 2176317
# 2321486
# 2322527
# 2771902
# 2449606
# 2326170
# 2258668
# 2326583
# 2698138
# 2326909
# 2326965
# 2258247
# 2258835
# 2609342
# 2327702
# 2533273
# 2257802
# 2256978
# 2462409
# 2533362
# 2328541
# 2853019
# 2149398
# 2329100
# 2329105
# 2329620
# 2269472
# 2266065
# 2330136
# 2330381
# 2269695
# 2522857
# 2331514
# 2331520
# 2331578
# 2331648
# 2331651
# 2707357
# 2289538
# 2333362
# 2457497
# 2333500
# 2458130
# 2333748
# 2334141
# 2334234
# 2287314
# 2334674
# 2288968
# 2704672
# 2335221
# 2290550
# 2263433
# 2336975
# 2263333
# 2337044
# 2263255
# 2263206
# 2337073
# 2263846
# 2864308
# 2337218
# 2337258
# 2337260
# 2264027
# 2337257
# 2264171
# 2337944
# 2338594
# 2339153
# 2339696
# 2339702
# 2340474
# 2635692
# 2340825
# 2340831
# 2296627
# 2296015
# 2322270
# 2317489
# 2342328
# 2475271
# 2342946
# 2573890
# 2343658
# 2290970
# 2345401
# 2298285
# 2346168
# 2549999
# 2637001
# 2572846
# 2346920
# 2636933
# 2698053
# 2756154
# 2688616
# 2347556
# 2348226
# 2309047
# 2348575
# 2313708
# 2520240
# 2349225
# 2807601
# 2614201
# 2684753
# 2477324
# 2320892
# 2351313
# 2567207
# 2351905
# 2352002
# 2574264
# 2352397
# 2352496
# 2352562
# 2352686
# 2352688
# 2352924
# 2453000
# 2353045
# 2353634
# 2827699
# 2309720
# 2762588
# 2246255
# 2355045
# 2355129
# 2355489
# 2355584
# 2356282
# 2487112
# 2356975
# 2357211
# 2740950
# 2414630
# 2241604
# 2739148
# 2358935
# 2359610
# 2360018
# 2655643
# 2738175
# 2426045
# 2361250
# 2200032
# 2361876
# 2362458
# 2362489
# 2362572
# 2362792
# 2362828
# 2362800
# 2489037
# 2363971
# 2195252
# 2195436
# 2364666
# 2364673
# 2594073
# 2364914
# 2365094
# 2365156
# 2206785
# 2365828
# 2365948
# 2366194
# 2366346
# 2367069
# 2204900
# 2205200
# 2368127
# 2368534
# 2368608
# 2627426
# 2368861
# 2369677
# 2369819
# 2471764
# 2371453
# 2563128
# 2371612
# 2470894
# 2372169
# 2372386
# 2372412
# 2372474
# 2372534
# 2372662
# 2372752
# 2373094
# 2537644
# 2374154
# 2252501
# 2251292
# 2374877
# 2375029
# 2375874
# 2376103
# 2493741
# 2376802
# 2376818
# 2377466
# 2236245
# 2377678
# 2233646
# 2872440
# 2667838
# 2427787
# 2427468
# 2234583
# 2378764
# 2378785
# 2378836
# 2378845
# 2379265
# 2379299
# 2380461
# 2559974
# 2381198
# 2381562
# 2237277
# 2383158
# 2384004
# 2384043
# 2437253
# 2385017
# 2385676
# 2386412
# 2299374
# 2386824
# 2387509
# 2387954
# 2388361
# 2388427
# 2301209
# 2388528
# 2389055
# 2390262
# 2539776
# 2879108
# 2468806
# 2642793
# 2642792
# 2243726
# 2392577
# 2392721
# 2880227
# 2393251
# 2722364
# 2394097
# 2208372
# 2395268
# 923028
# 2396097
# 2396124
# 2397118
# 2222148
# 2397759
# 2278794
# 2398583
# 2643556
# 2278936
# 2644006
# 2511997
# 2848473
# 2399320
# 2907431
# 2279358
# 2439193
# 2399570
# 2398289
# 2399709
# 2399711
# 2399763
# 2399784
# 2279666
# 2399891
# 2399918
# 2279842
# 2400154
# 2400199
# 2901349
# 2219847
# 2081038
# 2735275
# 2401510
# 2749617
# 2401839
# 2222803
# 2223004
# 2222999
# 2442371
# 2750386
# 2402766
# 2906467
# 2403335
# 2403720
# 2443049
# 2404500
# 2404559
# 2514576
# 2407156
# 2407398
# 2275840
# 2445016
# 2407784
# 2407850
# 2407934
# 2408098
# 2277185
# 2409372
# 2409640
# 2274098
# 2518439
# 2518392
# 2275492
# 2410522
# 2411300
# 2813508
# 2620942
# 2411871
# 2411636
# 2412658
# 2412832
# 2368089
# 2414188
# 2414477
# 2200257
# 2839783
# 2415033
# 2415764
# 2354862
# 2676647
# 2416921
# 2417547
# 2417596
# 2417643
# 2418087
# 2418374
# 2418616
# 2673736
# 2420041
# 2492492
# 2362587
# 2420654
# 2377031
# 2376874
# 2422389
# 2239272
# 2423969
# 2424868
# 2425590
# 2657023
# 2658932
# 2246367
# 2659127
# 2427026
# 2427290
# 2427445
# 2427973
# 2428509
# 2428714
# 2428920
# 2428970
# 2429046
# 2234822
# 2429576
# 2429624
# 2429843
# 2429988
# 2430015
# 2743681
# 2075837
# 2431184
# 2433069
# 2652251
# 2433773
# 2386500
# 2386467
# 2791610
# 2393789
# 2505692
# 2434779
# 2394724
# 2394413
# 2434899
# 2434904
# 2650839
# 2435221
# 2435372
# 1280765
# 2714531
# 2436599
# 2847345
# 2437590
# 2209307
# 2437694
# 2437712
# 2437718
# 2394237
# 2384757
# 2580038
# 2438313
# 2214908
# 2399369
# 2399256
# 2439380
# 2439849
# 2439886
# 2511726
# 2441564
# 2649101
# 2442440
# 2442973
# 2442990
# 2444709
# 2445300
# 2445425
# 2446226
# 2446229
# 2446312
# 2446333
# 2446734
# 2409984
# 2267408
# 384870
# 2447750
# 2447862
# 2448353
# 2448850
# 2448773
# 2448879
# 2449052
# 2449178
# 2449344
# 2854962
# 2450501
# 2855950
# 2451636
# 2452898
# 2353133
# 2453005
# 2348457
# 2308067
# 2929208
# 2453799
# 2453854
# 2453885
# 2350647
# 2454274
# 2267848
# 2454826
# 2454995
# 1737725
# 2456704
# 2151599
# 2333568
# 2333567
# 2457828
# 2458732
# 2459038
# 2459199
# 2410934
# 2334298
# 2700598
# 2337319
# 2337070
# 2337112
# 2864305
# 2327115
# 2327138
# 2462132
# 2257285
# 2462238
# 2699300
# 1546793
# 2327440
# 2326725
# 2326566
# 2326552
# 2257139
# 2327338
# 2463422
# 2816858
# 2464609
# 2465315
# 2395124
# 2466274
# 2466700
# 1853864
# 2467874
# 2393013
# 2469563
# 2163793
# 2470237
# 2470333
# 2232550
# 2772707
# 2470758
# 2868358
# 2471056
# 2471496
# 2471716
# 2374600
# 2473132
# 2375378
# 2773198
# 2474243
# 2474591
# 2695310
# 2342625
# 2477017
# 2351092
# 2477412
# 2477403
# 2762068
# 2477769
# 2830843
# 2478147
# 2478587
# 2320376
# 2479725
# 2479825
# 2481204
# 2481232
# 2481273
# 2481425
# 2481906
# 2481924
# 2339943
# 2571743
# 2776424
# 2412863
# 2484820
# 2485686
# 2485739
# 2365696
# 2486124
# 2101849
# 2486793
# 2486851
# 2487021
# 2487423
# 2487583
# 2487587
# 2487596
# 2487636
# 2177343
# 2105403
# 2777528
# 2414953
# 2680801
# 2840185
# 2488410
# 2488880
# 2364747
# 2417689
# 2489269
# 2798220
# 2489395
# 2417884
# 2418495
# 2490226
# 2781090
# 2490997
# 2491110
# 2491113
# 2491128
# 1974617
# 2492515
# 2492653
# 2492662
# 2492936
# 2493356
# 2493748
# 2493796
# 2493890
# 2494092
# 2494179
# 2494534
# 2633347
# 2495275
# 2379365
# 2424287
# 2496247
# 2426069
# 2657268
# 2497640
# 2787105
# 2498878
# 2499383
# 2499512
# 2428712
# 2428711
# 2501338
# 2501315
# 2501524
# 2794904
# 2501606
# 2388405
# 2502700
# 2503004
# 2503043
# 2503136
# 2503201
# 2895810
# 2503321
# 2504174
# 2433735
# 2300082
# 2434615
# 2506724
# 2506726
# 2507215
# 2507373
# 2507741
# 2507897
# 2508401
# 2437139
# 2509062
# 2847458
# 2509183
# 2595034
# 2509896
# 2279890
# 2644894
# 2510205
# 2510264
# 2511810
# 2511915
# 2512360
# 2513070
# 2513110
# 2223587
# 2514050
# 2514224
# 2514551
# 2405048
# 2443388
# 2406314
# 2443173
# 2516709
# 2516755
# 2516744
# 2517102
# 2518025
# 2409689
# 2518200
# 2518297
# 2518630
# 2518671
# 2518896
# 1591717
# 2519544
# 2520369
# 2610951
# 2520305
# 2268871
# 2520829
# 2520835
# 2521155
# 2325191
# 2063834
# 2522678
# 2269775
# 2525164
# 2525424
# 2311527
# 2525884
# 2526873
# 2528082
# 2528452
# 2528734
# 2460866
# 2529704
# 2916743
# 2529794
# 2530100
# 1341187
# 2530631
# 2530738
# 2530762
# 2530807
# 2334647
# 2334745
# 2531644
# 2531771
# 2608575
# 2013913
# 2263782
# 2461388
# 2865665
# 2532166
# 2805164
# 2460881
# 2532779
# 2815227
# 2336923
# 2532957
# 2533072
# 2327960
# 2534317
# 2286154
# 2534679
# 2535910
# 2536013
# 2536340
# 2537624
# 2372468
# 2878714
# 2324635
# 2540357
# 2119441
# 2541247
# 2542379
# 2542549
# 2369648
# 2543337
# 2034175
# 2543828
# 2543873
# 2369215
# 2544403
# 2627385
# 2544675
# 2544792
# 2544930
# 2545162
# 2474609
# 2545291
# 2545324
# 2546437
# 2548901
# 2550353
# 2294754
# 2551562
# 2552009
# 2552444
# 2297257
# 2553741
# 2373111
# 2555345
# 2467000
# 2771012
# 2390783
# 2558656
# 2880266
# 2496331
# 2237282
# 2240563
# 2561586
# 2562022
# 2768966
# 2542417
# 2562378
# 2541079
# 2766350
# 2562917
# 1615415
# 2765774
# 2563338
# 2626821
# 2563431
# 2564061
# 2495569
# 2565247
# 2547780
# 1410502
# 2567251
# 2567254
# 2567533
# 2567558
# 2060228
# 2567997
# 2568005
# 2454559
# 2569942
# 1917064
# 2526422
# 2571472
# 2571653
# 2572946
# 2573046
# 2574617
# 2574813
# 2575525
# 2577956
# 2515035
# 2747169
# 2508317
# 2501554
# 2501733
# 2501784
# 2581019
# 2430696
# 2581258
# 2503204
# 2514128
# 2583056
# 2489882
# 1900910
# 2511730
# 2407600
# 2407537
# 2202735
# 2587799
# 2587927
# 436706
# 2590979
# 2656058
# 2594138
# 2595103
# 2595341
# 2413252
# 2597569
# 2597816
# 2598292
# 2732607
# 2598732
# 2599420
# 1922932
# 2047014
# 2601793
# 2601899
# 2601912
# 2602361
# 2602379
# 2602532
# 2603137
# 2603246
# 2604128
# 2460054
# 2146444
# 2604944
# 2454756
# 2519852
# 2605928
# 860796
# 2328692
# 1498204
# 2606994
# 2606993
# 2607102
# 2328142
# 2533538
# 2607920
# 2258251
# 2533352
# 2533355
# 2610750
# 2610972
# 2568847
# 2611734
# 2525355
# 2612054
# 2148906
# 2612680
# 2612712
# 2913594
# 2614040
# 2614069
# 2614146
# 2351153
# 2618680
# 2619134
# 2534980
# 2599240
# 2619996
# 2620367
# 2620469
# 2620607
# 2705857
# 2620951
# 2621125
# 2602442
# 2602341
# 2621933
# 2531601
# 2530948
# 2259015
# 2609865
# 2623078
# 2623171
# 2533551
# 2609508
# 2623478
# 2624192
# 2702229
# 2624810
# 2625595
# 2919425
# 2607372
# 2607222
# 2731135
# 2607946
# 2541580
# 2563497
# 2541607
# 2627224
# 2628512
# 2630232
# 2630353
# 2630546
# 2630835
# 2493760
# 2494010
# 2631442
# 2631560
# 2631724
# 2239382
# 2561951
# 2591425
# 2499766
# 2563820
# 2635558
# 1708023
# 2637814
# 2638216
# 2639096
# 2639102
# 2469591
# 2640327
# 2641573
# 2641675
# 2641887
# 2642386
# 2585149
# 2584663
# 2398291
# 2644626
# 2646418
# 2646423
# 2646428
# 2403070
# 2675662
# 2647308
# 2582175
# 2649546
# 2649673
# 2649871
# 2436396
# 2650214
# 2714473
# 2650887
# 2593094
# 2652580
# 2652781
# 2653268
# 2503314
# 2747637
# 2580688
# 2654680
# 2654683
# 2592754
# 2655307
# 2425274
# 2655576
# 2656286
# 2656398
# 2739464
# 2656945
# 2657213
# 2590027
# 2658563
# 2658612
# 2658713
# 2658774
# 2658789
# 2657357
# 2659690
# 2659764
# 2659899
# 2732393
# 2661733
# 2675456
# 2778357
# 2663874
# 2484969
# 2664181
# 2664454
# 2422013
# 2768896
# 1963342
# 2665137
# 2665604
# 2665736
# 2631676
# 2666938
# 2667133
# 2667548
# 2656649
# 2667704
# 2668423
# 2668609
# 2670379
# 2671360
# 2926139
# 2092399
# 2673175
# 2194970
# 2832704
# 2489224
# 2903465
# 2676678
# 2676723
# 2659362
# 2677766
# 2657782
# 2678723
# 2355998
# 2679077
# 2679208
# 1961955
# 2681314
# 2681694
# 2682700
# 2682876
# 2684480
# 2684514
# 2825745
# 2934447
# 2684858
# 2351932
# 2685523
# 2349681
# 2686191
# 2613626
# 2686756
# 2687235
# 2519792
# 2856628
# 2171438
# 2526696
# 2689037
# 2611718
# 2690674
# 2690712
# 2690737
# 2692631
# 2694804
# 2343415
# 2697201
# 2698728
# 1329250
# 2625916
# 2700264
# 2731559
# 2625896
# 2702899
# 2531732
# 2703742
# 2703982
# 2703992
# 2704527
# 2621139
# 2705284
# 2705323
# 2705466
# 2530003
# 2705861
# 2705920
# 2706034
# 2706410
# 2706514
# 2749273
# 2707018
# 2625652
# 2729485
# 2707644
# 2708254
# 2333194
# 2708563
# 2715655
# 2709880
# 2585413
# 2080735
# 2711797
# 2712476
# 2712554
# 2222295
# 2713476
# 2797641
# 2714711
# 2714717
# 2715022
# 2508530
# 2715835
# 2437429
# 2847582
# 2716321
# 2716429
# 2717134
# 2717577
# 2717591
# 2717727
# 2717730
# 2718884
# 2719171
# 2704324
# 2860412
# 2720163
# 2703559
# 2720804
# 2708061
# 2721176
# 2722457
# 2701466
# 2651319
# 2846218
# 2722963
# 2723125
# 2724543
# 1194340
# 2724592
# 2154246
# 2411463
# 2724793
# 2724873
# 2725253
# 2411123
# 2602231
# 2725730
# 2609661
# 2727059
# 2727300
# 2727356
# 2686875
# 2908941
# 2728308
# 2730160
# 2623252
# 2730321
# 2730478
# 2730777
# 2855251
# 2700629
# 2626549
# 2700706
# 2700277
# 2732021
# 2732213
# 2191359
# 2597217
# 2676786
# 2734859
# 2734981
# 2735066
# 2490286
# 2735577
# 2736370
# 2488857
# 2892088
# 2737599
# 1690457
# 2838131
# 2738488
# 2738675
# 2738685
# 2738898
# 2590656
# 2739563
# 2589045
# 2427169
# 2742882
# 2795532
# 2900753
# 2746714
# 2746724
# 2654928
# 2503134
# 2580421
# 2748012
# 2748649
# 2749552
# 2401462
# 2647243
# 2751359
# 2751476
# 2751478
# 2645868
# 2752931
# 2475533
# 2573822
# 2755569
# 2755602
# 2698021
# 2297105
# 2697508
# 2756712
# 2756845
# 2756921
# 2757101
# 2757659
# 2758094
# 2758933
# 2758950
# 2758934
# 2759494
# 2267947
# 2761430
# 2684791
# 2762375
# 2309458
# 2683345
# 2763412
# 2764087
# 2764112
# 2764595
# 2541998
# 2766778
# 2766957
# 2376119
# 2767503
# 2769504
# 2469649
# 2539568
# 2871236
# 2773124
# 2627776
# 2669040
# 2773368
# 2774049
# 2833453
# 2776930
# 2776970
# 2777154
# 2777292
# 2487001
# 2364826
# 2778736
# 2779176
# 2779487
# 2779585
# 2780018
# 2664010
# 2659795
# 2363428
# 2491392
# 2597453
# 2631423
# 2782870
# 2782945
# 2783240
# 2783502
# 2785023
# 2785041
# 2785591
# 2892766
# 2785855
# 2787094
# 2788411
# 2788665
# 2788914
# 2789783
# 2789838
# 2790286
# 2581633
# 2595016
# 2791015
# 2791974
# 2746380
# 2847481
# 2793642
# 2794817
# 2718020
# 2794889
# 2796067
# 2796124
# 2748350
# 2796580
# 2418483
# 2798071
# 2798248
# 2584156
# 2799392
# 2651153
# 2800241
# 2800336
# 2802401
# 2802459
# 2802730
# 2802761
# 2802839
# 2803006
# 2803595
# 2702973
# 2725994
# 1729660
# 2730310
# 2805443
# 1927039
# 2726469
# 2807049
# 2808697
# 2613542
# 2809789
# 2809806
# 2809812
# 2448302
# 2703522
# 2719905
# 2811990
# 2812030
# 2602246
# 2813513
# 2862386
# 2814187
# 2867355
# 2531998
# 2730971
# 2706101
# 2818134
# 2818271
# 2819157
# 2770465
# 2536975
# 2469565
# 2380034
# 2821265
# 2822545
# 2772879
# 2354683
# 2827235
# 2881249
# 2757429
# 2829831
# 2830273
# 2831192
# 2831391
# 2832007
# 2832159
# 2832708
# 2833257
# 2776141
# 2413965
# 2834230
# 2712174
# 2400755
# 2799634
# 2835523
# 2401381
# 2835653
# 2835712
# 2835970
# 2597714
# 2836366
# 2779687
# 2837290
# 2837294
# 2837971
# 2838053
# 2429153
# 2838699
# 2838873
# 2632510
# 2838935
# 2839388
# 2788655
# 2840270
# 1962018
# 232428
# 2841607
# 2841678
# 2841981
# 2842418
# 2718505
# 2581052
# 2842960
# 2843754
# 2843807
# 2843966
# 2843975
# 2723115
# 2845587
# 2846132
# 2723312
# 2723316
# 2803226
# 2848665
# 2511036
# 1970107
# 2849325
# 2802594
# 2851843
# 2802347
# 2799846
# 2605626
# 2853852
# 2854173
# 2854519
# 2325393
# 2856450
# 2606353
# 2860436
# 2860924
# 2528342
# 2861038
# 2861138
# 2861187
# 2861487
# 2283863
# 2812449
# 2862254
# 2812155
# 2862563
# 2862640
# 2917651
# 2863573
# 2529985
# 2460832
# 1731546
# 2264165
# 2014457
# 2327169
# 2336876
# 2814823
# 2336912
# 2864936
# 2865295
# 2805830
# 2865720
# 2805853
# 2008812
# 2866037
# 2866076
# 2463674
# 2866576
# 2461703
# 2823817
# 2669613
# 2824378
# 2868668
# 2868965
# 2818884
# 2543911
# 2870731
# 2473587
# 2871228
# 2871261
# 2767174
# 2767016
# 2561830
# 2871722
# 2376009
# 2872183
# 2872405
# 2782915
# 2766913
# 2875506
# 2479149
# 2830895
# 2876676
# 2824818
# 2825065
# 2877410
# 2877547
# 2565140
# 2755040
# 2696844
# 2879137
# 2758220
# 2769557
# 2693156
# 2881443
# 2882130
# 2882192
# 2883676
# 2657974
# 2885470
# 2885518
# 2886379
# 2886826
# 2886929
# 2887418
# 2888130
# 2888147
# 2889572
# 2872112
# 2871462
# 2890802
# 2891590
# 2874654
# 2892048
# 2787529
# 2892511
# 2892632
# 2893343
# 2893442
# 2894563
# 2894619
# 2894705
# 2895123
# 2895795
# 2896276
# 2790277
# 2843764
# 2898023
# 2795543
# 2898107
# 2899123
# 2846294
# 2900632
# 2901357
# 2901426
# 2901553
# 2901626
# 2901750
# 2401546
# 2403092
# 2902430
# 2902830
# 2662360
# 2902969
# 2903151
# 2903672
# 2903763
# 2401171
# 2836643
# 2800197
# 2904536
# 2904721
# 2904789
# 2904792
# 2905009
# 2906247
# 2906770
# 2907053
# 2801772
# 2907959
# 2907960
# 2608883
# 2908384
# 2804355
# 2856016
# 2856093
# 2014172
# 2910201
# 2910230
# 2910615
# 2910646
# 2910820
# 2910854
# 2912224
# 2913410
# 2606339
# 2913891
# 2914436
# 2914588
# 2915338
# 2860824
# 2862092
# 2411367
# 2916812
# 2917849
# 2918220
# 2918394
# 2700682
# 2815219
# 2864020
# 2814446
# 2699882
# 2921260
# 2729386
# 2923220
# 2923356
# 2923402
# 2924292
# 2041924
# 586557
# 2926712
# 2869276
# 2926838
# 2928585
# 2763892
# 2681940
# 2930268
# 2931189
# 2932352
# 2932612
# 2753200
# 2932720
# 2933447
# 2933711
# 2934242
# 2934461
# 2574683
# 2875120
# 2685215
# 85.03176403045654
#               date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0       2013-02-01               0       59    22154      999.00           1.0
# 1       2013-03-01               0       25     2552      899.00           1.0
# 3       2013-06-01               0       25     2554     1709.05           1.0
# 4       2013-01-15               0       25     2555     1099.00           1.0
# 5       2013-10-01               0       25     2564      349.00           1.0
# ...            ...             ...      ...      ...         ...           ...
# 2935844 2015-10-10              33       25     7409      299.00           1.0
# 2935845 2015-09-10              33       25     7460      299.00           1.0
# 2935846 2015-10-14              33       25     7459      349.00           1.0
# 2935847 2015-10-22              33       25     7440      299.00           1.0
# 2935848 2015-03-10              33       25     7460      299.00           1.0
#
# [2928493 rows x 6 columns]

# %% [markdown]
# sales, test 합치기

# %%
s = train_F.copy()

# %%
s = pd.merge(s,test,left_on = ['item_id','shop_id'],right_on = ['item_id','shop_id'])

# %%
s
# Out:
#               date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0       2013-02-01               0       59    22154      999.00           1.0
# 1       2013-03-01               0       25     2552      899.00           1.0
# 3       2013-06-01               0       25     2554     1709.05           1.0
# 4       2013-01-15               0       25     2555     1099.00           1.0
# 5       2013-10-01               0       25     2564      349.00           1.0
# ...            ...             ...      ...      ...         ...           ...
# 2935844 2015-10-10              33       25     7409      299.00           1.0
# 2935845 2015-09-10              33       25     7460      299.00           1.0
# 2935846 2015-10-14              33       25     7459      349.00           1.0
# 2935847 2015-10-22              33       25     7440      299.00           1.0
# 2935848 2015-03-10              33       25     7460      299.00           1.0
#
# [2928493 rows x 6 columns]

# %% [markdown]
# ### item_shop_cnt_month 코드 추가

# %%
s.date_block_num, s.shop_id, s.item_id,
# Out:
# (0           0
#  1           0
#  2           0
#  3           0
#  4           0
#             ..
#  1221493    33
#  1221494    33
#  1221495    33
#  1221496    33
#  1221497    33
#  Name: date_block_num, Length: 1221498, dtype: int64,
#  0          59
#  1          25
#  2          25
#  3          25
#  4          25
#             ..
#  1221493    25
#  1221494    25
#  1221495    25
#  1221496    25
#  1221497    25
#  Name: shop_id, Length: 1221498, dtype: int64,
#  0          22154
#  1           2574
#  2           2574
#  3           2574
#  4           2574
#             ...
#  1221493     7327
#  1221494     7315
#  1221495     7409
#  1221496     7409
#  1221497     7409
#  Name: item_id, Length: 1221498, dtype: int64)

# %%
z = s[['date','date_block_num','shop_id','item_id','item_cnt_day']]
z
# Out:
#               date  date_block_num  shop_id  item_id  item_cnt_day
# 0       2013-02-01               0       59    22154           1.0
# 1       2013-03-01               0       25     2574           2.0
# 2       2013-05-01               0       25     2574           1.0
# 3       2013-07-01               0       25     2574           1.0
# 4       2013-08-01               0       25     2574           2.0
# ...            ...             ...      ...      ...           ...
# 1221493 2015-10-22              33       25     7327           1.0
# 1221494 2015-10-24              33       25     7315           1.0
# 1221495 2015-10-31              33       25     7409           1.0
# 1221496 2015-09-10              33       25     7409           1.0
# 1221497 2015-10-10              33       25     7409           1.0
#
# [1221498 rows x 5 columns]

# %%
k = z.groupby(by = ['date_block_num','shop_id','item_id']).mean()
k['item_shop_cnt_month'] = k.item_cnt_day
k.drop('item_cnt_day',axis = 1,inplace = True)
s.merge(k,left_on = ['date_block_num','shop_id','item_id'],right_on = ['date_block_num','shop_id','item_id'])
# Out:
#               date  date_block_num  shop_id  item_id  item_price  \
# 0       2013-02-01               0       59    22154       999.0
# 1       2013-03-01               0       25     2574       399.0
# 2       2013-05-01               0       25     2574       399.0
# 3       2013-07-01               0       25     2574       399.0
# 4       2013-08-01               0       25     2574       399.0
# ...            ...             ...      ...      ...         ...
# 1221493 2015-10-22              33       25     7327       349.0
# 1221494 2015-10-24              33       25     7315       399.0
# 1221495 2015-10-31              33       25     7409       299.0
# 1221496 2015-09-10              33       25     7409       299.0
# 1221497 2015-10-10              33       25     7409       299.0
#
#          item_cnt_day      ID  item_shop_cnt_month
# 0                 1.0  150983                  1.0
# 1                 2.0   56520                  1.3
# 2                 1.0   56520                  1.3
# 3                 1.0   56520                  1.3
# 4                 2.0   56520                  1.3
# ...               ...     ...                  ...
# 1221493           1.0   58974                  1.0
# 1221494           1.0   57353                  1.0
# 1221495           1.0   58431                  1.0
# 1221496           1.0   58431                  1.0
# 1221497           1.0   58431                  1.0
#
# [1221498 rows x 8 columns]
